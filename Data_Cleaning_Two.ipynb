# %%
import csv
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('UKdata.csv', na_values='')
#df

# %%
#dated 21th june
data = pd.read_csv('Final_UK.csv', na_values='')

# %%
data.head(5)
# Out:
#   CompanyNumber dissolutiondate incorporationdate   posttown county  \
# 0      SC421617             NaN        2012-04-11   ABERDEEN    NaN
# 1      07687209             NaN        2011-06-29     LONDON    NaN
# 2      02714021             NaN        1992-05-12   BROCKLEY    NaN
# 3      03811958             NaN        1999-07-22  TONBRIDGE   KENT
# 4      06439541             NaN        2007-11-28     SURREY    NaN
#
#           country  postcode          companycategory companystatus  siccode  \
# 0        SCOTLAND  AB11 6DJ  Private Limited Company        Active      NaN
# 1  UNITED KINGDOM  EC1M 7AD  Private Limited Company        Active  70229.0
# 2             NaN   SE4 1NQ  Private Limited Company        Active  90010.0
# 3             NaN  TN11 9PL  Private Limited Company        Active  70229.0
# 4             NaN  GU21 5TS  Private Limited Company        Active  99999.0
#
#                                       sicdescription RegAddress.PostCode  \
# ...

# %%
data['postcode'].count
# Out:
# <bound method Series.count of 0          AB11 6DJ
# 1          EC1M 7AD
# 2           SE4 1NQ
# 3          TN11 9PL
# 4          GU21 5TS
# 5            B3 1JJ
# 6           WD6 1JD
# 7           OL2 7DD
# 8           NW1 7EA
# 9           HA2 6AU
# 10          EH3 7JA
# 11         WC2B 6QX
# 12              NaN
# 13         LE12 7TZ
# 14          SM7 2NL
# 15          GU1 3DA
# 16          W12 8LA
# 17          NR2 2AL
# 18         PE30 1LT
# 19         DT11 0PX
# 20         LS22 6SN
# 21          NW3 1EH
# 22         LL17 0RD
# 23           N6 5HF
# 24         BT78 1LE
# 25          B37 7HG
# 26          NW7 2DQ
# 27          NE1 6QE
# 28          SG6 9BL
# 29              NaN
#              ...
# 1898957     G21 2PN
# 1898958      B3 2DL
# 1898959     FY8 5LU
# 1898960     HX5 9JR
# 1898961         NaN
# 1898962     ML3 6DA
# 1898963     SY2 6LG
# 1898964     HD5 0AB
# 1898965    EC2V 7NQ
# 1898966      B3 3SD
# 1898967      B3 2DB
# 1898968     IG1 4AQ
# 1898969     TN1 1JP
# ...

# %%
data.shape
# Out:
# (1898987, 18)

# %%
define=data.dropna(subset=['postcode','RegAddress.PostCode'])

# %%
define.columns
# Out:
# Index(['CompanyNumber', 'dissolutiondate', 'incorporationdate', 'posttown',
#        'county', 'country', 'postcode', 'companycategory', 'companystatus',
#        'siccode', 'sicdescription', 'RegAddress.PostCode', 'CompanyCategory',
#        'CompanyStatus', 'CountryOfOrigin', 'DissolutionDate',
#        'IncorporationDate', 'SICCode.SicText_1'],
#       dtype='object')

# %%
define.shape
# Out:
# (1870362, 18)

# %%
#this is to check is the postcode for 2013 SIC is matching with 2018 SIC
define['PC'] = np.where((define['postcode'] == define['RegAddress.PostCode']) 
                     , define['postcode'], np.nan)

# %%
define['SIC_2013']= define['siccode'].round(0)
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
define
# Out:
#         CompanyNumber dissolutiondate incorporationdate  \
# 0            SC421617             NaN        2012-04-11
# 1            07687209             NaN        2011-06-29
# 2            02714021             NaN        1992-05-12
# 3            03811958             NaN        1999-07-22
# 4            06439541             NaN        2007-11-28
# 5            05914136             NaN        2006-08-23
# 6            06473722             NaN        2008-01-15
# 7            04494986             NaN        2002-07-25
# 8            02537158             NaN        1990-09-05
# 9            05651002             NaN        2005-12-12
# 10           SC313991             NaN        2007-01-03
# 11           01784532             NaN        1984-01-19
# 13           05318740             NaN        2004-12-21
# 14           00807672             NaN        1964-06-03
# 15           07326397             NaN        2010-07-27
# 16           02871100             NaN        1993-11-12
# ...

# %%
decimals = 0    
define['SIC_2013'] = define['SIC_2013'].apply(lambda x: round(x, decimals))
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
define['SIC_2013']= define['SIC_2013'].fillna(0).astype(int)
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
define['SIC_2013']
# Out:
# 0              0
# 1          70229
# 2          90010
# 3          70229
# 4          99999
# 5          98000
# 6          56101
# 7          86230
# 8          73110
# 9          68209
# 10         82990
# 11         82990
# 13         82990
# 14             0
# 15         98000
# 16         68209
# 17         68320
# 18         56101
# 19         85310
# 20         45310
# 21         99999
# 22         88100
# 23         85200
# 24         41100
# 25         49320
# 26         96090
# 27         68209
# 28         47591
# 30         63990
# 31         86101
#            ...
# 1898952        0
# 1898953        0
# 1898955        0
# 1898956        0
# 1898957        0
# 1898958        0
# 1898959        0
# 1898960        0
# 1898962        0
# 1898963        0
# 1898964        0
# 1898965        0
# 1898966        0
# 1898967        0
# 1898968        0
# 1898969        0
# 1898970        0
# 1898971        0
# 1898972        0
# 1898973        0
# 1898974        0
# ...

# %%
print(type(np.nan))
# Out:
# <class 'float'>

# %%
define['SIC2018'].dtypes
# Out:
# dtype('O')

# %%
define[['SIC_2013','siccode','SIC2018']]
# Out:
#          SIC_2013  siccode        SIC2018
# 0               0      NaN          70229
# 1           70229  70229.0          70229
# 2           90010  90010.0          90010
# 3           70229  70229.0          70229
# 4           99999  99999.0          99999
# 5           98000  98000.0          98000
# 6           56101  56101.0          56101
# 7           86230  86230.0          86230
# 8           73110  73110.0          64209
# 9           68209  68209.0          68209
# 10          82990  82990.0          82990
# 11          82990  82990.0          46711
# 13          82990  82990.0          43220
# 14              0      NaN  None Supplied
# 15          98000  98000.0          98000
# 16          68209  68209.0          68100
# 17          68320  68320.0          68320
# 18          56101  56101.0          56101
# 19          85310  85310.0          85310
# 20          45310  45310.0          45310
# 21          99999  99999.0          74990
# ...

# %%
define.head(2)
# Out:
#   CompanyNumber dissolutiondate incorporationdate  posttown county  \
# 0      SC421617             NaN        2012-04-11  ABERDEEN    NaN
# 1      07687209             NaN        2011-06-29    LONDON    NaN
#
#           country  postcode          companycategory companystatus  siccode  \
# 0        SCOTLAND  AB11 6DJ  Private Limited Company        Active      NaN
# 1  UNITED KINGDOM  EC1M 7AD  Private Limited Company        Active  70229.0
#
#    ... RegAddress.PostCode          CompanyCategory CompanyStatus  \
# 0  ...            AB11 7SY  Private Limited Company        Active
# 1  ...            CM24 1SJ  Private Limited Company        Active
#
#   CountryOfOrigin DissolutionDate  IncorporationDate  \
# 0  United Kingdom             NaN         11/04/2012
# 1  United Kingdom             NaN         29/06/2011
#
#                                    SICCode.SicText_1 SIC_2013  SIC2018  \
# 0  70229 - Management consultancy activities othe...        0    70229
# ...

# %%
define.columns
# Out:
# Index(['CompanyNumber', 'dissolutiondate', 'incorporationdate', 'posttown',
#        'county', 'country', 'postcode', 'companycategory', 'companystatus',
#        'siccode', 'sicdescription', 'RegAddress.PostCode', 'CompanyCategory',
#        'CompanyStatus', 'CountryOfOrigin', 'DissolutionDate',
#        'IncorporationDate', 'SICCode.SicText_1', 'SIC_2013', 'SIC2018',
#        'description'],
#       dtype='object')

# %%
define = define.drop(['CompanyNumber', 'dissolutiondate', 'posttown',
       'county', 'country','siccode', 'sicdescription', 'CountryOfOrigin', 'DissolutionDate',
       'SICCode.SicText_1'],axis=1)

# %%
define.head(2)
# Out:
#   incorporationdate  postcode          companycategory companystatus  \
# 0        2012-04-11  AB11 6DJ  Private Limited Company        Active
# 1        2011-06-29  EC1M 7AD  Private Limited Company        Active
#
#   RegAddress.PostCode          CompanyCategory CompanyStatus  \
# 0            AB11 7SY  Private Limited Company        Active
# 1            CM24 1SJ  Private Limited Company        Active
#
#   IncorporationDate  SIC_2013 SIC2018  \
# 0        11/04/2012         0   70229
# 1        29/06/2011     70229   70229
#
#                                          description
# 0  Management consultancy activities other than f...
# 1  Management consultancy activities other than f...

# %%
define.to_csv('Data_SIC.csv',index=False)

# %%
define[['postcode','RegAddress.PostCode','PC']]
# Out:
#          postcode RegAddress.PostCode        PC
# 0        AB11 6DJ            AB11 7SY       NaN
# 1        EC1M 7AD            CM24 1SJ       NaN
# 2         SE4 1NQ             SE4 1NQ   SE4 1NQ
# 3        TN11 9PL            TN11 9PL  TN11 9PL
# 4        GU21 5TS            GU21 5TS  GU21 5TS
# 5          B3 1JJ            PO15 5SN       NaN
# 6         WD6 1JD             WD6 1JD   WD6 1JD
# 7         OL2 7DD             OL2 7DD   OL2 7DD
# 8         NW1 7EA              E1 7AA       NaN
# 9         HA2 6AU             HA2 6AU   HA2 6AU
# 10        EH3 7JA             EH1 2AE       NaN
# 11       WC2B 6QX            WC2B 6QX  WC2B 6QX
# 13       LE12 7TZ            LE12 7TZ  LE12 7TZ
# 14        SM7 2NL             SM7 2NL   SM7 2NL
# 15        GU1 3DA             HP2 7DN       NaN
# 16        W12 8LA             W12 8LA   W12 8LA
# 17        NR2 2AL             NR2 2AL   NR2 2AL
# 18       PE30 1LT            PE30 1LT  PE30 1LT
# 19       DT11 0PX            DT11 0PX  DT11 0PX
# ...

# %%
define.isna().sum()
# Out:
# incorporationdate           0
# postcode                    0
# companycategory             0
# companystatus               0
# RegAddress.PostCode         0
# CompanyCategory             0
# CompanyStatus               0
# IncorporationDate           0
# SIC_2013                    0
# SIC2018                     0
# description             62504
# PC                     722106
# dtype: int64

# %%
define_PC=define.dropna(subset=['PC'])

# %%
define_PC.shape
# the file contains postcode in similar format
# Out:
# (1148256, 12)

# %%
define_PC.head()
# Out:
#   incorporationdate  postcode          companycategory companystatus  \
# 2        1992-05-12   SE4 1NQ  Private Limited Company        Active
# 3        1999-07-22  TN11 9PL  Private Limited Company        Active
# 4        2007-11-28  GU21 5TS  Private Limited Company        Active
# 6        2008-01-15   WD6 1JD  Private Limited Company        Active
# 7        2002-07-25   OL2 7DD  Private Limited Company        Active
#
#   RegAddress.PostCode          CompanyCategory CompanyStatus  \
# 2             SE4 1NQ  Private Limited Company        Active
# 3            TN11 9PL  Private Limited Company        Active
# 4            GU21 5TS  Private Limited Company        Active
# 6             WD6 1JD  Private Limited Company        Active
# 7             OL2 7DD  Private Limited Company        Active
#
#   IncorporationDate  SIC_2013 SIC2018  \
# 2        12/05/1992     90010   90010
# 3        22/07/1999     70229   70229
# 4        28/11/2007     99999   99999
# ...

# %%
define_PC.columns
# Out:
# Index(['incorporationdate', 'postcode', 'companycategory', 'companystatus',
#        'RegAddress.PostCode', 'CompanyCategory', 'CompanyStatus',
#        'IncorporationDate', 'SIC_2013', 'SIC2018', 'description', 'PC'],
#       dtype='object')

# %%
#this is to check is the postcode for 2013 SIC is matching with 2018 SIC
define_PC['SICcombine'] = np.where((define_PC['SIC_2013'] == define_PC['SIC2018']) 
                     , define_PC['SIC_2013'], np.nan)
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
define_PC[['SICcombine','SIC_2013','SIC2018']]
# Out:
#         SICcombine SIC_2013        SIC2018
# 2            90010    90010          90010
# 3            70229    70229          70229
# 4            99999    99999          99999
# 6            56101    56101          56101
# 7            86230    86230          86230
# 9            68209    68209          68209
# 11             NaN    82990          46711
# 13             NaN    82990          43220
# 14             NaN        0  None Supplied
# 16             NaN    68209          68100
# 17           68320    68320          68320
# 18           56101    56101          56101
# 19           85310    85310          85310
# 20           45310    45310          45310
# 21             NaN    99999          74990
# 23           85200    85200          85200
# 24           41100    41100          41100
# 26           96090    96090          96090
# 28           47591    47591          47591
# 31           86101    86101          86101
# 33           98000    98000          98000
# ...

# %%
define_PC['SIC_2013']= define_PC['SIC_2013'].astype(str)
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
define_PC.dtypes
# Out:
# incorporationdate       object
# postcode                object
# companycategory         object
# companystatus           object
# RegAddress.PostCode     object
# CompanyCategory         object
# CompanyStatus           object
# IncorporationDate       object
# SIC_2013                object
# SIC2018                 object
# description             object
# PC                      object
# SICcombine             float64
# dtype: object

# %%
define_PC = define_PC.drop(['description', 'PC','RegAddress.PostCode'],axis=1)

# %%
define_PC.to_csv('Final.csv',index=False)

# %%
define.shape
# the file contains both sic code for 2013 and 2018
# Out:
# (1870362, 21)

# %%
define_PC.shape
# Out:
# (1148256, 10)

# %%
define.shape
#this is the uk data with postcose with nan values
# Out:
# (1872674, 18)

# %%
define['postcode'].count
# Out:
# <bound method Series.count of 0          AB11 6DJ
# 1          EC1M 7AD
# 2           SE4 1NQ
# 3          TN11 9PL
# 4          GU21 5TS
# 5            B3 1JJ
# 6           WD6 1JD
# 7           OL2 7DD
# 8           NW1 7EA
# 9           HA2 6AU
# 10          EH3 7JA
# 11         WC2B 6QX
# 13         LE12 7TZ
# 14          SM7 2NL
# 15          GU1 3DA
# 16          W12 8LA
# 17          NR2 2AL
# 18         PE30 1LT
# 19         DT11 0PX
# 20         LS22 6SN
# 21          NW3 1EH
# 22         LL17 0RD
# 23           N6 5HF
# 24         BT78 1LE
# 25          B37 7HG
# 26          NW7 2DQ
# 27          NE1 6QE
# 28          SG6 9BL
# 30          W1H 7AA
# 31          WF8 4BG
#              ...
# 1898952      S1 1WF
# 1898953     B28 0EL
# 1898955     HU8 7AJ
# 1898956    WA16 9PD
# 1898957     G21 2PN
# 1898958      B3 2DL
# 1898959     FY8 5LU
# 1898960     HX5 9JR
# 1898962     ML3 6DA
# 1898963     SY2 6LG
# 1898964     HD5 0AB
# 1898965    EC2V 7NQ
# 1898966      B3 3SD
# ...

# %%
define
# Out:
#         CompanyNumber dissolutiondate incorporationdate  \
# 0            SC421617             NaN        2012-04-11
# 1            07687209             NaN        2011-06-29
# 2            02714021             NaN        1992-05-12
# 3            03811958             NaN        1999-07-22
# 4            06439541             NaN        2007-11-28
# 5            05914136             NaN        2006-08-23
# 6            06473722             NaN        2008-01-15
# 7            04494986             NaN        2002-07-25
# 8            02537158             NaN        1990-09-05
# 9            05651002             NaN        2005-12-12
# 10           SC313991             NaN        2007-01-03
# 11           01784532             NaN        1984-01-19
# 13           05318740             NaN        2004-12-21
# 14           00807672             NaN        1964-06-03
# 15           07326397             NaN        2010-07-27
# 16           02871100             NaN        1993-11-12
# ...

# %%
define[['SIC2018','description']] = define['SICCode.SicText_1'].str.split(pat = " - ",expand=True)
#define
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3391: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %%
define.columns
# Out:
# Index(['CompanyNumber', 'dissolutiondate', 'incorporationdate', 'posttown',
#        'county', 'country', 'postcode', 'companycategory', 'companystatus',
#        'siccode', 'sicdescription', 'RegAddress.PostCode', 'CompanyCategory',
#        'CompanyStatus', 'CountryOfOrigin', 'DissolutionDate',
#        'IncorporationDate', 'SICCode.SicText_1', 'PC', 'SIC2018',
#        'description'],
#       dtype='object')

# %%
Finaldefine = define.drop(['CompanyNumber', 'dissolutiondate', 'posttown',
       'county', 'country', 'sicdescription', 'CountryOfOrigin', 'DissolutionDate',
       'SICCode.SicText_1','PC','RegAddress.PostCode'],axis=1)

# %%
Finaldefine.columns
# Out:
# Index(['incorporationdate', 'postcode', 'companycategory', 'companystatus',
#        'siccode', 'CompanyCategory', 'CompanyStatus', 'IncorporationDate',
#        'SIC2018', 'description'],
#       dtype='object')

# %%
Finaldefine.head(3)
# Out:
#   incorporationdate  postcode          companycategory companystatus  siccode  \
# 2        1992-05-12   SE4 1NQ  Private Limited Company        Active  90010.0
# 3        1999-07-22  TN11 9PL  Private Limited Company        Active  70229.0
# 4        2007-11-28  GU21 5TS  Private Limited Company        Active  99999.0
#
#            CompanyCategory CompanyStatus IncorporationDate SIC2018  \
# 2  Private Limited Company        Active        12/05/1992   90010
# 3  Private Limited Company        Active        22/07/1999   70229
# 4  Private Limited Company        Active        28/11/2007   99999
#
#                                          description
# 2                                    Performing arts
# 3  Management consultancy activities other than f...
# 4                                    Dormant Company

# %%
Finaldefine['sic_2013'] = round(Finaldefine['siccode'],0)
Finaldefine
# Out:
#         incorporationdate  postcode  \
# 2              1992-05-12   SE4 1NQ
# 3              1999-07-22  TN11 9PL
# 4              2007-11-28  GU21 5TS
# 6              2008-01-15   WD6 1JD
# 7              2002-07-25   OL2 7DD
# 9              2005-12-12   HA2 6AU
# 11             1984-01-19  WC2B 6QX
# 13             2004-12-21  LE12 7TZ
# 14             1964-06-03   SM7 2NL
# 16             1993-11-12   W12 8LA
# 17             1978-08-07   NR2 2AL
# 18             2002-04-30  PE30 1LT
# 19             1927-11-26  DT11 0PX
# 20             1998-12-21  LS22 6SN
# 21             1986-11-21   NW3 1EH
# 23             1899-07-27    N6 5HF
# 24             2006-05-16  BT78 1LE
# 26             2004-08-20   NW7 2DQ
# 28             1996-12-19   SG6 9BL
# 31             1984-03-07   WF8 4BG
# 33             1985-10-02   TQ1 3NT
# 34             1998-07-03  BT82 8DX
# 35             1965-06-14   BR3 5BZ
# 36             2009-03-02   B18 6EW
# 38             1998-07-29   IG1 1BA
# ...

# %%
Finaldefine

# %%
#this is to check is the postcode for 2013 SIC is matching with 2018 SIC
Finaldefine['PC'] = np.where((Finaldefine['postcode'] == Finaldefine['RegAddress.PostCode']) 
                     , Finaldefine['postcode'], np.nan)

# %%
#If they're equal, that statement will return True, else False.
Finaldefine['postcode'].equals(Finaldefine['RegAddress.PostCode'])

# %%
SIC2018 = define['SICCode.SicText_1'].str.split(pat = " - ",expand=True)

# %%
SIC2018.head(2)
# Out:
#        0                                                  1
# 0  70229  Management consultancy activities other than f...
# 1  70229  Management consultancy activities other than f...

# %%
SIC2018.rename(columns={0:'SIC_2018',1:'SIC_description'})
# Out:
#               SIC_2018                                    SIC_description
# 0                70229  Management consultancy activities other than f...
# 1                70229  Management consultancy activities other than f...
# 2                90010                                    Performing arts
# 3                70229  Management consultancy activities other than f...
# 4                99999                                    Dormant Company
# 5                98000                      Residents property management
# 6                56101                               Licensed restaurants
# 7                86230                         Dental practice activities
# 8                64209       Activities of other holding companies n.e.c.
# 9                68209  Other letting and operating of own or leased r...
# 10               82990   Other business support service activities n.e.c.
# 11               46711      Wholesale of petroleum and petroleum products
# ...

# %%
define['SICCode.SicText_1']
# Out:
# 0          70229 - Management consultancy activities othe...
# 1          70229 - Management consultancy activities othe...
# 2                                    90010 - Performing arts
# 3          70229 - Management consultancy activities othe...
# 4                                    99999 - Dormant Company
# 5                      98000 - Residents property management
# 6                               56101 - Licensed restaurants
# 7                         86230 - Dental practice activities
# 8          64209 - Activities of other holding companies ...
# 9          68209 - Other letting and operating of own or ...
# 10         82990 - Other business support service activit...
# 11         46711 - Wholesale of petroleum and petroleum p...
# 13         43220 - Plumbing, heat and air-conditioning in...
# 14                                             None Supplied
# 15                     98000 - Residents property management
# ...

# %%
data.dtypes
# Out:
# CompanyNumber           object
# dissolutiondate         object
# incorporationdate       object
# posttown                object
# county                  object
# country                 object
# postcode                object
# companycategory         object
# companystatus           object
# siccode                float64
# sicdescription          object
# RegAddress.PostCode     object
# CompanyCategory         object
# CompanyStatus           object
# CountryOfOrigin         object
# DissolutionDate        float64
# IncorporationDate       object
# SICCode.SicText_1       object
# dtype: object

# %%
# Digital technologies
sic_digital = [26110,26120,26200,26400,26511,26512,26800,33130,
                58210,58290,62011,62012,62020,62030,62090,63110,
                63120,95110]

# %%
sic_digital[2]
# Out:
# 26200

# %%
# Life Sciences and healthcare
sic_science = [21100,21200,26600,26701,32500,72110,75000,86101,
                86102,86210,86220,86230,86900]

# %%
# Publishing and broadcasting
sic_publishing = [26301,26309,26702,58110,58120,58130,58141,58142,
                   58190,59111,59112,59113,59120,59131,59132,59133,
                   59140,59200,60100,60200,61100,61200, 61300,61900,
                   63910,63990,73110,73120,73200,74100,74201,74202,
                   74203,74209,95120]
# Other scientific activities of manufacturing
sic_otherScManuf = [19201,19209,20110,20120,20130,95210,95220,95250,
                     20140,20150,20160,20170,20200,20301,20302,20411,
                     20412,20420,20510,20520,20530,20590,20600,25210,
                     25300,25400,26513,26514,26520,27110,27120,27200,
                     27310,27320,27330,27400,27510,27520,27900,28110,
                     28120,28131,28132,28140,28150,28210,28220,28230,
                     28240,28250,28290,28301,28302,28410,28490,28910,
                     28921,28922,28923,28930,28940,28950,28960,28990,
                     29100,29201,29202,29203,29310,29320,30110,30120,
                     30200,30300,30400,30910,30920,30990,32120,32401,
                     33120,33140,33150,33160,33170]
# Other scientific activity services
sic_otherScServices = [51101,51102,51210,51220,71111,71112,71121,71122,
                        71129,71200,72190,72200,74901,74902,85410,85421,
                        85422]

# %%
# Food and accomodation
sic_food = [55100,55201,55202,55209,55300, 56101,56102,56103,
             56210,56290,56301,56302]
# Entertainment
sic_entertainment = [59140, 82301,82302, 90010,91011,91012,91020,91030,
                      91040,92000,93110, 93120,93130,93191,93199, 93020]
# Retail except retail trade of motor vehicles
sic_retail = [47190,47990,47290,47789,47782,47810,47890,47820,
               47781,47110,47791,47430,47300,47250,47610,47240,
               47530,47710,47410,47750,47540,47230,47760,47721,
               47210,47599,47650,47520,47741,47722,47220,47749,
               47421,47630,47591,47620,47799,47640,47429,47510,
               47260,47770,47910]

# %%
#Pharma industry is 21200
df.loc['SICCode.SicText_1'] = '21200'

# %%
df.loc['siccode']
# Out:
# postcode             21200
# siccode              21200
# posttown             21200
# SICCode.SicText_1    21200
# county               21200
# country              21200
# Name: siccode, dtype: object

# %%
df.loc[:, 'siccode']
# Out:
# 0            NaN
# 1          70229
# 2          90010
# 3          70229
# 4          99999
# 5          98000
# 6          56101
# 7          86230
# 8          73110
# 9          68209
# 10         82990
# 11         82990
# 12           NaN
# 13         82990
# 14           NaN
# 15         98000
# 16         68209
# 17         68320
# 18         56101
# 19         85310
# 20         45310
# 21         99999
# 22         88100
# 23         85200
# 24         41100
# 25         49320
# 26         96090
# 27         68209
# 28         47591
# 29           NaN
#            ...
# 1898958      NaN
# 1898959      NaN
# 1898960      NaN
# 1898961      NaN
# 1898962      NaN
# 1898963      NaN
# 1898964      NaN
# 1898965      NaN
# 1898966      NaN
# 1898967      NaN
# 1898968      NaN
# 1898969      NaN
# 1898970      NaN
# 1898971      NaN
# 1898972      NaN
# 1898973      NaN
# 1898974      NaN
# 1898975      NaN
# 1898976      NaN
# 1898977      NaN
# 1898978      NaN
# ...

# %%
df.loc[df['siccode'] =='21200']
# Out:
#         postcode siccode posttown SICCode.SicText_1 county country
# siccode    21200   21200    21200             21200  21200   21200

# %%
df.loc[[0,1,2], :]
# Out:
#    postcode siccode  posttown  \
# 0  AB11 6DJ     NaN  ABERDEEN
# 1  EC1M 7AD   70229    LONDON
# 2   SE4 1NQ   90010  BROCKLEY
#
#                                    SICCode.SicText_1 county         country
# 0  70229 - Management consultancy activities othe...    NaN        SCOTLAND
# 1  70229 - Management consultancy activities othe...    NaN  UNITED KINGDOM
# 2                            90010 - Performing arts    NaN             NaN

# %%
df.rename(columns={'SICCode.SicText_1':'SIC2018','siccode':'SIC2013'},inplace=True)
print(df.head(4))
# Out:
#    postcode  SIC2013   posttown  \
# 0  AB11 6DJ      NaN   ABERDEEN
# 1  EC1M 7AD  70229.0     LONDON
# 2   SE4 1NQ  90010.0   BROCKLEY
# 3  TN11 9PL  70229.0  TONBRIDGE
#
#                                              SIC2018 county         country
# 0  70229 - Management consultancy activities othe...    NaN        SCOTLAND
# 1  70229 - Management consultancy activities othe...    NaN  UNITED KINGDOM
# 2                            90010 - Performing arts    NaN             NaN
# 3  70229 - Management consultancy activities othe...   KENT             NaN

# %%
df.loc[:, 'SIC2018']
# Out:
# 0          70229 - Management consultancy activities othe...
# 1          70229 - Management consultancy activities othe...
# 2                                    90010 - Performing arts
# 3          70229 - Management consultancy activities othe...
# 4                                    99999 - Dormant Company
# 5                      98000 - Residents property management
# 6                               56101 - Licensed restaurants
# 7                         86230 - Dental practice activities
# 8          64209 - Activities of other holding companies ...
# 9          68209 - Other letting and operating of own or ...
# 10         82990 - Other business support service activit...
# 11         46711 - Wholesale of petroleum and petroleum p...
# 12                                             None Supplied
# 13         43220 - Plumbing, heat and air-conditioning in...
# 14                                             None Supplied
# ...

# %%
df.loc[:, 'SIC2013']
# Out:
# 0              NaN
# 1          70229.0
# 2          90010.0
# 3          70229.0
# 4          99999.0
# 5          98000.0
# 6          56101.0
# 7          86230.0
# 8          73110.0
# 9          68209.0
# 10         82990.0
# 11         82990.0
# 12             NaN
# 13         82990.0
# 14             NaN
# 15         98000.0
# 16         68209.0
# 17         68320.0
# 18         56101.0
# 19         85310.0
# 20         45310.0
# 21         99999.0
# 22         88100.0
# 23         85200.0
# 24         41100.0
# 25         49320.0
# 26         96090.0
# 27         68209.0
# 28         47591.0
# 29             NaN
#             ...
# 1898957        NaN
# 1898958        NaN
# 1898959        NaN
# 1898960        NaN
# 1898961        NaN
# 1898962        NaN
# 1898963        NaN
# 1898964        NaN
# 1898965        NaN
# 1898966        NaN
# 1898967        NaN
# 1898968        NaN
# 1898969        NaN
# 1898970        NaN
# 1898971        NaN
# 1898972        NaN
# ...

# %%
Pharma2013 = df[df.SIC2013=='21200']

# %%
Pharma2013.head()
# Out:
# Empty DataFrame
# Columns: [postcode, SIC2013, posttown, SIC2018, county, country]
# Index: []

# %%
df.posttown
# Out:
# 0                        ABERDEEN
# 1                          LONDON
# 2                        BROCKLEY
# 3                       TONBRIDGE
# 4                          SURREY
# 5                      BIRMINGHAM
# 6                   HERTFORDSHIRE
# 7                          OLDHAM
# 8                          LONDON
# 9                       MIDDLESEX
# 10                      EDINBURGH
# 11                         LONDON
# 12                            NaN
# 13                   LOUGHBOROUGH
# 14                         SURREY
# 15                      GUILDFORD
# 16                            NaN
# 17                        NORFOLK
# 18                     KINGS LYNN
# 19                         DORSET
# 20                       WETHERBY
# 21                         LONDON
# 22               ST ASAPH,DENBIGH
# 23                       HIGHGATE
# 24                          OMAGH
# 25                  MARSTON GREEN
# 26                         LONDON
# ...

# %%
Pharma2018.head()
# Out:
#        postcode  SIC2013      posttown  \
# 57136   HA1 4HF  21200.0  NORTH HARROW
# 58506  OL16 2LJ      NaN      ROCHDALE
# 60234   NW1 1JD  72190.0        LONDON
# 61154  TN22 1QG  21200.0      UCKFIELD
# 61935  EX32 8NS  21200.0    BARNSTAPLE
#
#                                                  SIC2018       county  \
# 57136  21200 - Manufacture of pharmaceutical preparat...    MIDDLESEX
# 58506  21200 - Manufacture of pharmaceutical preparat...          NaN
# 60234  21200 - Manufacture of pharmaceutical preparat...          NaN
# 61154  21200 - Manufacture of pharmaceutical preparat...  EAST SUSSEX
# 61935  21200 - Manufacture of pharmaceutical preparat...        DEVON
#
#               country
# 57136  UNITED KINGDOM
# 58506         ENGLAND
# 60234             NaN
# 61154  UNITED KINGDOM
# 61935             NaN

# %%
Pharma2018
# Out:
#          postcode  SIC2013                       posttown  \
# 57136     HA1 4HF  21200.0                   NORTH HARROW
# 58506    OL16 2LJ      NaN                       ROCHDALE
# 60234     NW1 1JD  72190.0                         LONDON
# 61154    TN22 1QG  21200.0                       UCKFIELD
# 61935    EX32 8NS  21200.0                     BARNSTAPLE
# 61937    EX32 8NS  21200.0                          DEVON
# 63081     WN2 3XD  62090.0                     LANCASHIRE
# 72971     SA3 4QE  21200.0                        SWANSEA
# 77453     BS8 3BA  21200.0                        BRISTOL
# 81299    PE27 5JL  21200.0                        ST IVES
# 82478     L15 4LP  25620.0                      LIVERPOOL
# 85555     CH8 9DN  21200.0                       HOLYWELL
# 93873    BN14 8SA  21200.0                    WEST SUSSEX
# 93874    BN14 8SA  21200.0                    WEST SUSSEX
# 94058     DL1 2PA  21200.0     DODWORTH STREET,DARLINGTON
# ...

# %%
Pharma2018.county
# Out:
# 57136           MIDDLESEX
# 58506                 NaN
# 60234                 NaN
# 61154         EAST SUSSEX
# 61935               DEVON
# 61937                 NaN
# 63081                 NaN
# 72971      WEST GLAMORGAN
# 77453                AVON
# 81299      CAMBRIDGESHIRE
# 82478          MERSEYSIDE
# 85555          FLINTSHIRE
# 93873                 NaN
# 93874                 NaN
# 94058           CO DURHAM
# 94390           WILTSHIRE
# 96203                 NaN
# 98933                YORK
# 102415                NaN
# 115510                NaN
# 122921     WEST YORKSHIRE
# 123174        OXFORDSHIRE
# 123671                NaN
# 126211                NaN
# 136543         LANCASHIRE
# 154190                NaN
# 154279           CHESHIRE
# 159224                NaN
# 159807                NaN
# 167579                NaN
#                 ...
# 1659741               NaN
# 1685386               NaN
# 1685592               NaN
# 1688708           WREXHAM
# ...

# %%
#Pharma2018.loc['country']

# %%
Pharma2018.loc[Pharma2018.country=='ENGLAND', 'county']
# Out:
# 58506                 NaN
# 77453                AVON
# 81299      CAMBRIDGESHIRE
# 102415                NaN
# 210354                NaN
# 226954                NaN
# 327791                NaN
# 340218        OXFORDSHIRE
# 355933         DERBYSHIRE
# 698878      HERTFORDSHIRE
# 724552     LEICESTERSHIRE
# 726162          MIDDLESEX
# 766400                NaN
# 869101                NaN
# 920497                NaN
# 934488      STAFFORDSHIRE
# 942817      STAFFORDSHIRE
# 1008673               NaN
# 1050617    LEICESTERSHIRE
# 1129335    GREATER LONDON
# 1134417            SURREY
# 1143076       OXFORDSHIRE
# 1178120             LINCS
# 1188164               NaN
# 1188379               NaN
# 1237890          CHESHIRE
# 1361921           ENGLAND
# 1396501               NaN
# 1463925    CAMBRIDGESHIRE
# 1623151               NaN
# 1726855        LANCASHIRE
# 1732792               NaN
# 1769179               NaN
# 1796221               NaN
# 1823224               NaN
# ...

# %%
Pharma2018.loc[Pharma2018.county=='ENGLAND', 'country']
# Out:
# 1361921    ENGLAND
# Name: country, dtype: object

# %%
Pharma2018.to_csv("Pharma2018.csv", index=False)

# %%
Pharma2013 = df[df.SIC2013=='21200.0']
Pharma2013
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/pandas/core/ops.py:1649: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# Empty DataFrame
# Columns: [postcode, SIC2013, posttown, SIC2018, county, country]
# Index: []

# %%
Pharma2013.SIC2013
# Out:
# Series([], Name: SIC2013, dtype: float64)

# %%
df.SIC2013=='21200.0'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1898957    False
# 1898958    False
# 1898959    False
# 1898960    False
# 1898961    False
# 1898962    False
# 1898963    False
# 1898964    False
# 1898965    False
# 1898966    False
# 1898967    False
# 1898968    False
# 1898969    False
# 1898970    False
# 1898971    False
# 1898972    False
# 1898973    False
# 1898974    False
# 1898975    False
# 1898976    False
# 1898977    False
# ...
