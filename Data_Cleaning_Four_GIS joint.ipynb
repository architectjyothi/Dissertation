# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('sicdata13.csv',na_values='')
df.head(5)
# Out:
#   incorporationdate  postcode  SIC2018 company2013 company2018
# 0        2009-01-05   RG1 2QU    45200      Active      Active
# 1        2009-01-05  SW17 7PY    62020      Active      Active
# 2        2009-01-05  DE55 7HH    84250      Active      Active
# 3        2009-01-05   SL7 3DF    56102      Active      Active
# 4        2009-01-05    G1 4AG    93199      Active   NotActive

# %%
df
# Out:
#        incorporationdate  postcode  SIC2018 company2013 company2018
# 0             2009-01-05   RG1 2QU    45200      Active      Active
# 1             2009-01-05  SW17 7PY    62020      Active      Active
# 2             2009-01-05  DE55 7HH    84250      Active      Active
# 3             2009-01-05   SL7 3DF    56102      Active      Active
# 4             2009-01-05    G1 4AG    93199      Active   NotActive
# 5             2009-01-05  SW1W 9QQ    99999      Active      Active
# 6             2009-01-05   N21 3NA    99999      Active      Active
# 7             2009-01-05   BB9 7AW    59112      Active      Active
# 8             2009-01-05   SK6 5DW    74100      Active      Active
# 9             2009-01-05   N12 8RT    55100      Active      Active
# 10            2009-01-05   HA9 8HB    46180      Active      Active
# 11            2009-01-05   HA9 8HA    69202      Active      Active
# 12            2009-01-05  WC2A 3PE    94990      Active      Active
# ...

# %%
data=pd.read_csv('SIC_integer.csv',na_values='')
data.head(5)
# Out:
#   incorporationdate  postcode          companycategory companystatus  \
# 0        1992-05-12   SE4 1NQ  Private Limited Company        Active
# 1        1999-07-22  TN11 9PL  Private Limited Company        Active
# 2        2007-11-28  GU21 5TS  Private Limited Company        Active
# 3        2008-01-15   WD6 1JD  Private Limited Company        Active
# 4        2002-07-25   OL2 7DD  Private Limited Company        Active
#
#            CompanyCategory CompanyStatus IncorporationDate  SIC_2013  SIC2018  \
# 0  Private Limited Company        Active        12/05/1992     90010    90010
# 1  Private Limited Company        Active        22/07/1999     70229    70229
# 2  Private Limited Company        Active        28/11/2007     99999    99999
# 3  Private Limited Company        Active        15/01/2008     56101    56101
# 4  Private Limited Company        Active        25/07/2002     86230    86230
#
#    SICcombine
# 0     90010.0
# 1     70229.0
# 2     99999.0
# 3     56101.0
# ...

# %%
data
# Out:
#         incorporationdate  postcode  \
# 0              1992-05-12   SE4 1NQ
# 1              1999-07-22  TN11 9PL
# 2              2007-11-28  GU21 5TS
# 3              2008-01-15   WD6 1JD
# 4              2002-07-25   OL2 7DD
# 5              2005-12-12   HA2 6AU
# 6              1984-01-19  WC2B 6QX
# 7              2004-12-21  LE12 7TZ
# 8              1964-06-03   SM7 2NL
# 9              1993-11-12   W12 8LA
# 10             1978-08-07   NR2 2AL
# 11             2002-04-30  PE30 1LT
# 12             1927-11-26  DT11 0PX
# 13             1998-12-21  LS22 6SN
# 14             1986-11-21   NW3 1EH
# 15             1899-07-27    N6 5HF
# 16             2006-05-16  BT78 1LE
# 17             2004-08-20   NW7 2DQ
# 18             1996-12-19   SG6 9BL
# 19             1984-03-07   WF8 4BG
# 20             1985-10-02   TQ1 3NT
# 21             1998-07-03  BT82 8DX
# 22             1965-06-14   BR3 5BZ
# 23             2009-03-02   B18 6EW
# 24             1998-07-29   IG1 1BA
# ...

# %%
data.dtypes
# Out:
# incorporationdate     object
# postcode              object
# companycategory       object
# companystatus         object
# CompanyCategory       object
# CompanyStatus         object
# IncorporationDate     object
# SIC_2013               int64
# SIC2018                int64
# SICcombine           float64
# dtype: object

# %%
data=data.set_index('postcode')

# %%
postcode = pd.read_csv('/Users/jyothigupta/Documents/UCL/GIS/GIS class/week 1/Postcode.csv',na_values='')
postcode.head(5)
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       pcd7      pcd8      pcds  dointr  doterm  usertype     oa11cd  \
# 0  AB118RJ  AB11 8RJ  AB11 8RJ  199606       0         0  S00089089
# 1  AB116WH  AB11 6WH  AB11 6WH  199606       0         0  S00090554
# 2  AB116YW  AB11 6YW  AB11 6YW  199606       0         1  S00090575
# 3  AB118RL  AB11 8RL  AB11 8RL  199606       0         0  S00089089
# 4  AB118YB  AB11 8YB  AB11 8YB  199707  199801         1  S00090467
#
#     lsoa11cd   msoa11cd      ladcd               lsoa11nm          msoa11nm  \
# 0  S01006635  S02001258  S12000033        Torry East - 05        Torry East
# 1  S01006591  S02001251  S12000033   Ferryhill North - 01   Ferryhill North
# ...

# %%
postcode[['pcd7','pcd8','pcds']]
# Out:
#             pcd7      pcd8      pcds
# 0        AB118RJ  AB11 8RJ  AB11 8RJ
# 1        AB116WH  AB11 6WH  AB11 6WH
# 2        AB116YW  AB11 6YW  AB11 6YW
# 3        AB118RL  AB11 8RL  AB11 8RL
# 4        AB118YB  AB11 8YB  AB11 8YB
# 5        AB116WJ  AB11 6WJ  AB11 6WJ
# 6        AB116YX  AB11 6YX  AB11 6YX
# 7        AB118RN  AB11 8RN  AB11 8RN
# 8        AB118YD  AB11 8YD  AB11 8YD
# 9        AB116WL  AB11 6WL  AB11 6WL
# 10       AB116ZA  AB11 6ZA  AB11 6ZA
# 11       AB118RP  AB11 8RP  AB11 8RP
# 12       AB118YE  AB11 8YE  AB11 8YE
# 13       AB116WN  AB11 6WN  AB11 6WN
# 14       AB118AA  AB11 8AA  AB11 8AA
# 15       AB119JJ  AB11 9JJ  AB11 9JJ
# 16       AB117SY  AB11 7SY  AB11 7SY
# 17       AB116ZB  AB11 6ZB  AB11 6ZB
# 18       AB116ZD  AB11 6ZD  AB11 6ZD
# 19       AB116ZE  AB11 6ZE  AB11 6ZE
# 20       AB116ZF  AB11 6ZF  AB11 6ZF
# 21       AB116ZG  AB11 6ZG  AB11 6ZG
# 22       AB116ZH  AB11 6ZH  AB11 6ZH
# 23       AB116ZJ  AB11 6ZJ  AB11 6ZJ
# ...

# %%
#this is to check is the postcode for 2013 SIC is matching with 2018 SIC
postcode['Postcode'] = np.where((postcode['pcd7'] == postcode['pcd8']) 
                     , postcode['pcd7'], np.nan)

# %%
postcode['Postcode']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
#           ...
# 2616808    NaN
# 2616809    NaN
# 2616810    NaN
# 2616811    NaN
# 2616812    NaN
# 2616813    NaN
# 2616814    NaN
# 2616815    NaN
# 2616816    NaN
# 2616817    NaN
# 2616818    NaN
# 2616819    NaN
# 2616820    NaN
# 2616821    NaN
# 2616822    NaN
# 2616823    NaN
# 2616824    NaN
# 2616825    NaN
# 2616826    NaN
# 2616827    NaN
# 2616828    NaN
# 2616829    NaN
# 2616830    NaN
# 2616831    NaN
# 2616832    NaN
# 2616833    NaN
# 2616834    NaN
# ...

# %%
postcode
# Out:
#             pcd7      pcd8      pcds  dointr  doterm  usertype     oa11cd  \
# 0        AB118RJ  AB11 8RJ  AB11 8RJ  199606       0         0  S00089089
# 1        AB116WH  AB11 6WH  AB11 6WH  199606       0         0  S00090554
# 2        AB116YW  AB11 6YW  AB11 6YW  199606       0         1  S00090575
# 3        AB118RL  AB11 8RL  AB11 8RL  199606       0         0  S00089089
# 4        AB118YB  AB11 8YB  AB11 8YB  199707  199801         1  S00090467
# 5        AB116WJ  AB11 6WJ  AB11 6WJ  200207  200311         1  S00090554
# 6        AB116YX  AB11 6YX  AB11 6YX  200302  200604         1  S00090392
# 7        AB118RN  AB11 8RN  AB11 8RN  199606       0         0  S00089095
# 8        AB118YD  AB11 8YD  AB11 8YD  199612  199712         1  S00089080
# 9        AB116WL  AB11 6WL  AB11 6WL  200201  200203         1  S00090554
# 10       AB116ZA  AB11 6ZA  AB11 6ZA  199612  200309         1  S00090392
# 11       AB118RP  AB11 8RP  AB11 8RP  199606       0         0  S00089096
# ...

# %%
postcode.columns
# Out:
# Index(['pcd7', 'pcd8', 'pcds', 'dointr', 'doterm', 'usertype', 'oa11cd',
#        'lsoa11cd', 'msoa11cd', 'ladcd', 'lsoa11nm', 'msoa11nm', 'ladnm',
#        'ladnmw', 'FID', 'Postcode'],
#       dtype='object')

# %%
postcode = postcode.drop(['pcd7', 'pcd8', 'dointr',
       'doterm', 'ladnmw', 'Postcode'],axis=1)

# %%
postcode.head(3)
# Out:
#        pcds  usertype     oa11cd   lsoa11cd   msoa11cd      ladcd  \
# 0  AB11 8RJ         0  S00089089  S01006635  S02001258  S12000033
# 1  AB11 6WH         0  S00090554  S01006591  S02001251  S12000033
# 2  AB11 6YW         1  S00090575  S01006582  S02001249  S12000033
#
#                 lsoa11nm          msoa11nm          ladnm   FID
# 0        Torry East - 05        Torry East  Aberdeen City  4001
# 1   Ferryhill North - 01   Ferryhill North  Aberdeen City  4002
# 2  City Centre West - 01  City Centre West  Aberdeen City  4003

# %%
postcode= postcode.set_index('pcds')

# %%
#merged = a.merge(b, on='ID')
result = postcode.join(data)

# %%
joined = data.join(postcode)

# %%
joined.head()
# Out:
#        incorporationdate      companycategory companystatus  \
# 06 830        2008-05-28  Limited Partnership        Active
# 06 830        2008-05-28  Limited Partnership        Active
# 06 830        2008-05-28  Limited Partnership        Active
# 06 830        2008-05-28  Limited Partnership        Active
# 06 830        2008-05-28  Limited Partnership        Active
#
#             CompanyCategory CompanyStatus IncorporationDate  SIC_2013  \
# 06 830  Limited Partnership        Active        28/05/2008         0
# 06 830  Limited Partnership        Active        28/05/2008         0
# 06 830  Limited Partnership        Active        28/05/2008         0
# 06 830  Limited Partnership        Active        28/05/2008         0
# 06 830  Limited Partnership        Active        28/05/2008         0
#
#         SIC2018  SICcombine  usertype oa11cd lsoa11cd msoa11cd ladcd lsoa11nm  \
# 06 830        0         NaN       NaN    NaN      NaN      NaN   NaN      NaN
# ...

# %%
joined
# Out:
#            incorporationdate  \
# 06 830            2008-05-28
# 06 830            2008-05-28
# 06 830            2008-05-28
# 06 830            2008-05-28
# 06 830            2008-05-28
# 06 830            2008-06-20
# 06 830            2008-06-20
# 06 830            2008-06-20
# 06 830            2008-07-24
# 06 830            2007-12-27
# 19808 USA         2012-09-26
# 20 006            2010-05-28
# 20004-2505        2006-11-22
# 3 7BG             1966-12-07
# 60 606            2011-11-16
# 8                 1922-09-06
# AB1 1PU           1982-01-14
# AB1 1PU           1984-04-23
# AB1 1PU           1981-10-21
# AB1 1PU           1984-01-13
# AB1 1PU           1993-06-30
# AB1 1PU           1981-02-23
# AB1 1PU           1991-05-22
# AB1 1UL           1988-03-28
# AB1 1UL           1972-04-14
# AB1 1XL           1990-09-26
# AB1 1XL           1991-04-03
# AB1 1YL           1984-12-05
# AB1 1YL           1966-01-04
# AB1 1YL           1897-11-16
# ...                      ...
# ...

# %%
joined.to_csv('Joined_Postcode.csv',index=True)

# %%
PC=pd.read_csv('Joined_Postcode.csv',na_values='')
PC.head(3)
# Out:
#   Postcode incorporationdate      companycategory companystatus  \
# 0   06 830        28/05/2008  Limited Partnership        Active
# 1   06 830        28/05/2008  Limited Partnership        Active
# 2   06 830        28/05/2008  Limited Partnership        Active
#
#        CompanyCategory CompanyStatus IncorporationDate  SIC_2013  SIC2018  \
# 0  Limited Partnership        Active        28/05/2008         0        0
# 1  Limited Partnership        Active        28/05/2008         0        0
# 2  Limited Partnership        Active        28/05/2008         0        0
#
#    SICcombine  usertype oa11cd lsoa11cd msoa11cd ladcd lsoa11nm msoa11nm  \
# 0         NaN       NaN    NaN      NaN      NaN   NaN      NaN      NaN
# 1         NaN       NaN    NaN      NaN      NaN   NaN      NaN      NaN
# 2         NaN       NaN    NaN      NaN      NaN   NaN      NaN      NaN
#
#   ladnm  FID
# 0   NaN  NaN
# 1   NaN  NaN
# 2   NaN  NaN

# %%
PC.count()
# Out:
# Postcode             1048575
# incorporationdate    1048575
# companycategory      1048575
# companystatus        1048575
# CompanyCategory      1048575
# CompanyStatus        1048575
# IncorporationDate    1048575
# SIC_2013             1048575
# SIC2018              1048575
# SICcombine            790851
# usertype             1045637
# oa11cd               1045571
# lsoa11cd             1045571
# msoa11cd             1045571
# ladcd                1045571
# lsoa11nm             1045571
# msoa11nm             1045571
# ladnm                1040139
# FID                  1045637
# dtype: int64

# %%
PC.sum()

# %%
result.head()
# Out:
#          usertype     oa11cd   lsoa11cd   msoa11cd      ladcd  \
# AB1 0AA         0  S00090303  S01006514  S02001237  S12000033
# AB1 0AB         0  S00090303  S01006514  S02001237  S12000033
# AB1 0AD         0  S00090399  S01006514  S02001237  S12000033
# AB1 0AE         0  S00091322  S01006853  S02001296  S12000034
# AB1 0AF         1  S00090299  S01006511  S02001236  S12000033
#
#                                           lsoa11nm  \
# AB1 0AA  Cults, Bieldside and Milltimber West - 02
# AB1 0AB  Cults, Bieldside and Milltimber West - 02
# AB1 0AD  Cults, Bieldside and Milltimber West - 02
# AB1 0AE           Dunecht, Durris and Drumoak - 01
# AB1 0AF                                Culter - 06
#
#                                     msoa11nm          ladnm  FID  \
# AB1 0AA  Cults, Bieldside and Milltimber Wes  Aberdeen City    4
# AB1 0AB  Cults, Bieldside and Milltimber Wes  Aberdeen City   20
# AB1 0AD  Cults, Bieldside and Milltimber Wes  Aberdeen City   28
# ...
