# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('Joined_Postcode.csv',na_values='')

# %%
df.head(4)
# Out:
#   Postcode incorporationdate      companycategory companystatus  \
# 0   06 830        28/05/2008  Limited Partnership        Active
# 1   06 830        28/05/2008  Limited Partnership        Active
# 2   06 830        28/05/2008  Limited Partnership        Active
# 3   06 830        28/05/2008  Limited Partnership        Active
#
#        CompanyCategory CompanyStatus IncorporationDate  SIC_2013  SIC2018  \
# 0  Limited Partnership        Active        28/05/2008         0        0
# 1  Limited Partnership        Active        28/05/2008         0        0
# 2  Limited Partnership        Active        28/05/2008         0        0
# 3  Limited Partnership        Active        28/05/2008         0        0
#
#    SICcombine  usertype oa11cd lsoa11cd msoa11cd ladcd lsoa11nm msoa11nm  \
# 0         NaN       NaN    NaN      NaN      NaN   NaN      NaN      NaN
# 1         NaN       NaN    NaN      NaN      NaN   NaN      NaN      NaN
# ...

# %%
df.shape
# Out:
# (1048575, 19)

# %%
df_post= df.set_index('Postcode')

# %%
df_post[['SIC_2013','SIC2018','SICcombine']]
# Out:
#             SIC_2013  SIC2018  SICcombine
# Postcode
# 06 830             0        0         NaN
# 06 830             0        0         NaN
# 06 830             0        0         NaN
# 06 830             0        0         NaN
# 06 830             0        0         NaN
# 06 830             0        0         NaN
# 06 830             0        0         NaN
# 06 830             0        0         NaN
# 06 830             0        0         NaN
# 06 830             0        0         NaN
# 19808 USA          0        0         NaN
# 20 006             0        0         NaN
# 20004-2505         0        0         NaN
# 3 7BG              0        0         NaN
# 60 606             0        0         NaN
# 8                  0        0         NaN
# AB1 1PU        52290    52290     52290.0
# AB1 1PU        50300    50300     50300.0
# AB1 1PU        52290    50200         NaN
# AB1 1PU        50200    50200     50200.0
# AB1 1PU        96090    96090     96090.0
# ...

# %%
SICdata=pd.read_csv('SIC_integer.csv',na_values='')

# %%
SICdata.head(5)
# Out:
#   incorporationdate  postcode          companycategory companystatus  \
# 0        1992-05-12   SE4 1NQ  Private Limited Company        Active
# 1        1999-07-22  TN11 9PL  Private Limited Company        Active
# 2        2007-11-28  GU21 5TS  Private Limited Company        Active
# 3        2008-01-15   WD6 1JD  Private Limited Company        Active
# 4        2002-07-25   OL2 7DD  Private Limited Company        Active
#
#            CompanyCategory CompanyStatus IncorporationDate  SIC_2013  SIC2018  \
# 0  Private Limited Company        Active        12/05/1992     90010    90010
# 1  Private Limited Company        Active        22/07/1999     70229    70229
# 2  Private Limited Company        Active        28/11/2007     99999    99999
# 3  Private Limited Company        Active        15/01/2008     56101    56101
# 4  Private Limited Company        Active        25/07/2002     86230    86230
#
#    SICcombine
# 0     90010.0
# 1     70229.0
# 2     99999.0
# 3     56101.0
# ...

# %%
SICdata.shape
# Out:
# (1148256, 10)

# %%
postcode = pd.read_csv('/Users/jyothigupta/Documents/UCL/GIS/GIS class/week 1/Postcode.csv',na_values='')
postcode.head(5)
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       pcd7      pcd8      pcds  dointr  doterm  usertype     oa11cd  \
# 0  AB118RJ  AB11 8RJ  AB11 8RJ  199606       0         0  S00089089
# 1  AB116WH  AB11 6WH  AB11 6WH  199606       0         0  S00090554
# 2  AB116YW  AB11 6YW  AB11 6YW  199606       0         1  S00090575
# 3  AB118RL  AB11 8RL  AB11 8RL  199606       0         0  S00089089
# 4  AB118YB  AB11 8YB  AB11 8YB  199707  199801         1  S00090467
#
#     lsoa11cd   msoa11cd      ladcd               lsoa11nm          msoa11nm  \
# 0  S01006635  S02001258  S12000033        Torry East - 05        Torry East
# 1  S01006591  S02001251  S12000033   Ferryhill North - 01   Ferryhill North
# ...

# %%
postcode.shape
# Out:
# (2616838, 15)

# %%
postcode= postcode.set_index('pcds')
postcode.head(4)
# Out:
#              pcd7      pcd8  dointr  doterm  usertype     oa11cd   lsoa11cd  \
# pcds
# AB11 8RJ  AB118RJ  AB11 8RJ  199606       0         0  S00089089  S01006635
# AB11 6WH  AB116WH  AB11 6WH  199606       0         0  S00090554  S01006591
# AB11 6YW  AB116YW  AB11 6YW  199606       0         1  S00090575  S01006582
# AB11 8RL  AB118RL  AB11 8RL  199606       0         0  S00089089  S01006635
#
#            msoa11cd      ladcd               lsoa11nm          msoa11nm  \
# pcds
# AB11 8RJ  S02001258  S12000033        Torry East - 05        Torry East
# AB11 6WH  S02001251  S12000033   Ferryhill North - 01   Ferryhill North
# AB11 6YW  S02001249  S12000033  City Centre West - 01  City Centre West
# AB11 8RL  S02001258  S12000033        Torry East - 05        Torry East
#
#                   ladnm ladnmw   FID
# pcds
# AB11 8RJ  Aberdeen City    NaN  4001
# AB11 6WH  Aberdeen City    NaN  4002
# AB11 6YW  Aberdeen City    NaN  4003
# AB11 8RL  Aberdeen City    NaN  4004

# %%
postcode.head(3)
# Out:
#       pcd7      pcd8      pcds  dointr  doterm  usertype     oa11cd  \
# 0  AB118RJ  AB11 8RJ  AB11 8RJ  199606       0         0  S00089089
# 1  AB116WH  AB11 6WH  AB11 6WH  199606       0         0  S00090554
# 2  AB116YW  AB11 6YW  AB11 6YW  199606       0         1  S00090575
#
#     lsoa11cd   msoa11cd      ladcd               lsoa11nm          msoa11nm  \
# 0  S01006635  S02001258  S12000033        Torry East - 05        Torry East
# 1  S01006591  S02001251  S12000033   Ferryhill North - 01   Ferryhill North
# 2  S01006582  S02001249  S12000033  City Centre West - 01  City Centre West
#
#            ladnm ladnmw   FID
# 0  Aberdeen City    NaN  4001
# 1  Aberdeen City    NaN  4002
# 2  Aberdeen City    NaN  4003

# %%
data = pd.read_csv('ukpostcodes.csv',na_values='')

# %%
data_post= data.set_index('postcode')

# %%
data_post.head(4)
# Out:
#           id   latitude  longitude
# postcode
# AB10 1XG   1  57.144165  -2.114848
# AB10 6RN   2  57.137880  -2.121487
# AB10 7JB   3  57.124274  -2.127190
# AB11 5QN   4  57.142701  -2.093295

# %%
data_post.shape
# Out:
# (1765734, 3)

# %%
joined = data_post.join(postcode)

# %%
joined.shape
# Out:
# (1765734, 17)

# %%
joined.head(4)
# Out:
#           id   latitude  longitude     pcd7      pcd8    dointr  doterm  \
# postcode
# AB10 1XG   1  57.144165  -2.114848  AB101XG  AB10 1XG  199606.0     0.0
# AB10 6RN   2  57.137880  -2.121487  AB106RN  AB10 6RN  199606.0     0.0
# AB10 7JB   3  57.124274  -2.127190  AB107JB  AB10 7JB  199606.0     0.0
# AB11 5QN   4  57.142701  -2.093295  AB115QN  AB11 5QN  199606.0     0.0
#
#           usertype     oa11cd   lsoa11cd   msoa11cd      ladcd  \
# postcode
# AB10 1XG       0.0  S00088970  S01006571  S02001247  S12000033
# AB10 6RN       0.0  S00089205  S01006576  S02001248  S12000033
# AB10 7JB       0.0  S00089357  S01006530  S02001239  S12000033
# AB11 5QN       0.0  S00090582  S01006587  S02001250  S12000033
#
#                        lsoa11nm          msoa11nm          ladnm ladnmw  \
# postcode
# AB10 1XG    West End North - 01    West End North  Aberdeen City    NaN
# AB10 6RN    West End South - 02    West End South  Aberdeen City    NaN
# ...

# %%
joined
# Out:
#                id   latitude  longitude     pcd7      pcd8    dointr  doterm  \
# postcode
# AB10 1XG        1  57.144165  -2.114848  AB101XG  AB10 1XG  199606.0     0.0
# AB10 6RN        2  57.137880  -2.121487  AB106RN  AB10 6RN  199606.0     0.0
# AB10 7JB        3  57.124274  -2.127190  AB107JB  AB10 7JB  199606.0     0.0
# AB11 5QN        4  57.142701  -2.093295  AB115QN  AB11 5QN  199606.0     0.0
# AB11 6UL        5  57.137547  -2.112233  AB116UL  AB11 6UL  199606.0     0.0
# AB11 8RQ        6  57.135978  -2.072115  AB118RQ  AB11 8RQ  199606.0     0.0
# AB12 3FJ        7  57.098003  -2.077438  AB123FJ  AB12 3FJ  199606.0     0.0
# AB12 4NA        8  57.064273  -2.130018  AB124NA  AB12 4NA  199606.0     0.0
# AB12 5GL        9  57.081938  -2.246567  AB125GL  AB12 5GL  199606.0     0.0
# AB12 9SP       10  57.148707  -2.097806  AB129SP  AB12 9SP  200502.0     0.0
# AB14 0TQ       11  57.101557  -2.268486  AB140TQ  AB14 0TQ  199606.0     0.0
# ...

# %%
joined = joined.drop(['id','pcd7', 'pcd8', 'dointr',
       'doterm', 'usertype','ladnmw'],axis=1)

# %%
joined.to_csv('Postcode_coordinates.csv',index=True)

# %%
joined.head(3)
# Out:
#            latitude  longitude     oa11cd   lsoa11cd   msoa11cd      ladcd  \
# postcode
# AB10 1XG  57.144165  -2.114848  S00088970  S01006571  S02001247  S12000033
# AB10 6RN  57.137880  -2.121487  S00089205  S01006576  S02001248  S12000033
# AB10 7JB  57.124274  -2.127190  S00089357  S01006530  S02001239  S12000033
#
#                      lsoa11nm        msoa11nm          ladnm     FID
# postcode
# AB10 1XG  West End North - 01  West End North  Aberdeen City  3015.0
# AB10 6RN  West End South - 02  West End South  Aberdeen City  3146.0
# AB10 7JB        Garthdee - 05        Garthdee  Aberdeen City  3489.0

# %%
joined.isnull().sum().sum()
# Out:
# 24564

# %%
joined.shape
# Out:
# (1765734, 10)

# %%
joined.isnull().any().any()
# Out:
# True

# %%
joined.dropna()
# Out:
#            latitude  longitude     oa11cd   lsoa11cd   msoa11cd      ladcd  \
# postcode
# AB10 1XG  57.144165  -2.114848  S00088970  S01006571  S02001247  S12000033
# AB10 6RN  57.137880  -2.121487  S00089205  S01006576  S02001248  S12000033
# AB10 7JB  57.124274  -2.127190  S00089357  S01006530  S02001239  S12000033
# AB11 5QN  57.142701  -2.093295  S00090582  S01006587  S02001250  S12000033
# AB11 6UL  57.137547  -2.112233  S00090560  S01006597  S02001251  S12000033
# AB11 8RQ  57.135978  -2.072115  S00089114  S01006631  S02001258  S12000033
# AB12 3FJ  57.098003  -2.077438  S00090233  S01006619  S02001256  S12000033
# AB12 4NA  57.064273  -2.130018  S00092225  S01006851  S02001295  S12000034
# AB12 5GL  57.081938  -2.246567  S00091322  S01006853  S02001296  S12000034
# AB12 9SP  57.148707  -2.097806  S00090540  S01006646  S02001261  S12000033
# AB14 0TQ  57.101557  -2.268486  S00090294  S01006507  S02001236  S12000033
# ...

# %%
joined.shape
# Out:
# (1765734, 10)

# %%
nan_rows = joined[joined['msoa11cd'].isnull()]

# %%
nan_lad_rows = joined[joined['ladcd'].isnull()]

# %%
nan_lad_rows
# Out:
#            latitude  longitude oa11cd lsoa11cd msoa11cd ladcd lsoa11nm  \
# postcode
# IV51 0AE  99.999999   0.000000    NaN      NaN      NaN   NaN      NaN
# BN91 9AA  50.923170  -0.346777    NaN      NaN      NaN   NaN      NaN
# BD98 1GA  53.983502  -2.013688    NaN      NaN      NaN   NaN      NaN
# BD98 1GB  54.052625  -2.051348    NaN      NaN      NaN   NaN      NaN
# BD98 1GD  53.752752  -1.778608    NaN      NaN      NaN   NaN      NaN
# BD98 1GG  53.880912  -2.057586    NaN      NaN      NaN   NaN      NaN
# BD98 1YA  54.086296  -2.101362    NaN      NaN      NaN   NaN      NaN
# BD98 1YB  54.007521  -1.888642    NaN      NaN      NaN   NaN      NaN
# BD98 1YD  53.876774  -1.907758    NaN      NaN      NaN   NaN      NaN
# BD98 1YY  54.199320  -2.290625    NaN      NaN      NaN   NaN      NaN
# BD98 5GA  54.003071  -1.958101    NaN      NaN      NaN   NaN      NaN
# BD98 5GG  54.101570  -1.971505    NaN      NaN      NaN   NaN      NaN
# ...

# %%
nan_rows
# Out:
#            latitude  longitude oa11cd lsoa11cd msoa11cd ladcd lsoa11nm  \
# postcode
# IV51 0AE  99.999999   0.000000    NaN      NaN      NaN   NaN      NaN
# BN91 9AA  50.923170  -0.346777    NaN      NaN      NaN   NaN      NaN
# BD98 1GA  53.983502  -2.013688    NaN      NaN      NaN   NaN      NaN
# BD98 1GB  54.052625  -2.051348    NaN      NaN      NaN   NaN      NaN
# BD98 1GD  53.752752  -1.778608    NaN      NaN      NaN   NaN      NaN
# BD98 1GG  53.880912  -2.057586    NaN      NaN      NaN   NaN      NaN
# BD98 1YA  54.086296  -2.101362    NaN      NaN      NaN   NaN      NaN
# BD98 1YB  54.007521  -1.888642    NaN      NaN      NaN   NaN      NaN
# BD98 1YD  53.876774  -1.907758    NaN      NaN      NaN   NaN      NaN
# BD98 1YY  54.199320  -2.290625    NaN      NaN      NaN   NaN      NaN
# BD98 5GA  54.003071  -1.958101    NaN      NaN      NaN   NaN      NaN
# BD98 5GG  54.101570  -1.971505    NaN      NaN      NaN   NaN      NaN
# ...

# %%
joined.isna()
# Out:
#           latitude  longitude  oa11cd  lsoa11cd  msoa11cd  ladcd  lsoa11nm  \
# postcode
# AB10 1XG     False      False   False     False     False  False     False
# AB10 6RN     False      False   False     False     False  False     False
# AB10 7JB     False      False   False     False     False  False     False
# AB11 5QN     False      False   False     False     False  False     False
# AB11 6UL     False      False   False     False     False  False     False
# AB11 8RQ     False      False   False     False     False  False     False
# AB12 3FJ     False      False   False     False     False  False     False
# AB12 4NA     False      False   False     False     False  False     False
# AB12 5GL     False      False   False     False     False  False     False
# AB12 9SP     False      False   False     False     False  False     False
# AB14 0TQ     False      False   False     False     False  False     False
# ...

# %%
finaljoined = joined.dropna()

# %%
finaljoined.shape
# Out:
# (1749015, 10)

# %%
finaljoined.to_csv('Postcode_coordinates.csv',index=True)

# %%
population = pd.read_csv('/Users/jyothigupta/Documents/UCL/CASA_Dissertations/UrbanScalinglaw/Data/population/population.csv',na_values='')

# %%
population.head(2)
# Out:
#    Area code  population      Males    Females  Lives in a household  \
# 0  W92000004   3063456.0  1504228.0  1559228.0             3011182.0
# 1  W92000004   3063456.0  1504228.0  1559228.0             3011182.0
#
#    Lives in a communal establishment  Schoolchild       Area   Density
# 0                            52274.0       35061.0  2073511.0      1.5
# 1                            52274.0       35061.0  2073511.0      1.5

# %%
population.shape
# Out:
# (464, 9)

# %%
population= population.set_index('Area code')
population.head(4)
# Out:
#            population      Males    Females  Lives in a household  \
# Area code
# W92000004   3063456.0  1504228.0  1559228.0             3011182.0
# W92000004   3063456.0  1504228.0  1559228.0             3011182.0
# W06000024     58802.0    28791.0    30011.0               58334.0
# W06000023    132976.0    65683.0    67293.0              131047.0
#
#            Lives in a communal establishment  Schoolchild       Area   Density
# Area code
# W92000004                            52274.0       35061.0  2073511.0      1.5
# W92000004                            52274.0       35061.0  2073511.0      1.5
# W06000024                              468.0         474.0    11139.0      5.3
# W06000023                             1929.0        2117.0   518037.0      0.3

# %%
population.dtypes
# Out:
# population                           float64
# Males                                float64
# Females                              float64
# Lives in a household                 float64
# Lives in a communal establishment    float64
# Schoolchild                          float64
# Area                                 float64
# Density                              float64
# dtype: object

# %%
population.isna()
# Out:
#                                                     population  Males  \
# Area code
# W92000004                                                False  False
# W92000004                                                False  False
# W06000024                                                False  False
# W06000023                                                False  False
# W06000022                                                False  False
# W06000021                                                False  False
# W06000020                                                False  False
# W06000019                                                False  False
# W06000018                                                False  False
# W06000016                                                False  False
# W06000015                                                False  False
# W06000014                                                False  False
# ...

# %%
pop = population.dropna()

# %%
pop.isna()
# Out:
#             population  Males  Females  Lives in a household  \
# Area code
# W92000004        False  False    False                 False
# W92000004        False  False    False                 False
# W06000024        False  False    False                 False
# W06000023        False  False    False                 False
# W06000022        False  False    False                 False
# W06000021        False  False    False                 False
# W06000020        False  False    False                 False
# W06000019        False  False    False                 False
# W06000018        False  False    False                 False
# W06000016        False  False    False                 False
# W06000015        False  False    False                 False
# W06000014        False  False    False                 False
# W06000013        False  False    False                 False
# W06000012        False  False    False                 False
# ...

# %%
pop.dtypes
# Out:
# population                           float64
# Males                                float64
# Females                              float64
# Lives in a household                 float64
# Lives in a communal establishment    float64
# Schoolchild                          float64
# Area                                 float64
# Density                              float64
# dtype: object

# %%
pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 461 entries, W92000004 to 95A
# Data columns (total 8 columns):
# population                           461 non-null float64
# Males                                461 non-null float64
# Females                              461 non-null float64
# Lives in a household                 461 non-null float64
# Lives in a communal establishment    461 non-null float64
# Schoolchild                          461 non-null float64
# Area                                 461 non-null float64
# Density                              461 non-null float64
# dtypes: float64(8)
# memory usage: 32.4+ KB

# %%
pop['population'].astype('int')
# Out:
# Area code
# W92000004     3063456
# W92000004     3063456
# W06000024       58802
# W06000023      132976
# W06000022      145736
# W06000021       91323
# W06000020       91075
# W06000019       69814
# W06000018      178806
# W06000016      234410
# W06000015      346090
# W06000014      126336
# W06000013      139178
# W06000012      139812
# W06000011      239023
# W06000010      183777
# W06000009      122439
# W06000008       75922
# W06000006      134844
# W06000005      152506
# W06000004       93734
# W06000003      115228
# W06000002      121874
# W06000001       69751
# S92000003     5295403
# S92000003     5295403
# S12000046      593245
# S12000045      105026
# S12000044      337727
# S12000042      147268
#                ...
# E06000004      191610
# E06000003      135177
# E06000002      138412
# E06000001       92028
# 95Z            280962
# 95Y             67242
# 95X             78078
# 95W             78937
# 95V             39114
# 95U             85139
# ...

# %%
pop.dtypes
# Out:
# population                           float64
# Males                                float64
# Females                              float64
# Lives in a household                 float64
# Lives in a communal establishment    float64
# Schoolchild                          float64
# Area                                 float64
# Density                              float64
# dtype: object

# %%
pop["population"] = pop['population'].astype('int')
pop.dtypes
# Out:
# population                             int64
# Males                                float64
# Females                              float64
# Lives in a household                 float64
# Lives in a communal establishment    float64
# Schoolchild                          float64
# Area                                 float64
# Density                              float64
# dtype: object

# %%
pop.head()
# Out:
#            population      Males    Females  Lives in a household  \
# Area code
# W92000004     3063456  1504228.0  1559228.0             3011182.0
# W92000004     3063456  1504228.0  1559228.0             3011182.0
# W06000024       58802    28791.0    30011.0               58334.0
# W06000023      132976    65683.0    67293.0              131047.0
# W06000022      145736    71380.0    74356.0              144103.0
#
#            Lives in a communal establishment  Schoolchild       Area   Density
# Area code
# W92000004                            52274.0       35061.0  2073511.0      1.5
# W92000004                            52274.0       35061.0  2073511.0      1.5
# W06000024                              468.0         474.0    11139.0      5.3
# W06000023                             1929.0        2117.0   518037.0      0.3
# W06000022                             1633.0        1509.0    19052.0      7.6

# %%
pop['Males'].astype('int')
pop['Females'].astype('int')
pop['Lives in a household'].astype('int')
pop['Lives in a communal establishment'].astype('int')
# Out:
# Area code
# W92000004     52274
# W92000004     52274
# W06000024       468
# W06000023      1929
# W06000022      1633
# W06000021      1629
# W06000020       715
# W06000019       575
# W06000018      1051
# W06000016      2525
# W06000015     11539
# W06000014      2077
# W06000013      2336
# W06000012      1130
# W06000011      4660
# W06000010      2550
# W06000009      1894
# W06000008      4478
# W06000006      1600
# W06000005       827
# W06000004      1251
# W06000003      2697
# W06000002      3900
# W06000001       810
# S92000003     99017
# S92000003     99017
# S12000046     14994
# S12000045       595
# S12000044      2410
# S12000042      5167
#               ...
# E06000004      3651
# E06000003      1248
# E06000002      2256
# E06000001       937
# 95Z            4821
# 95Y             740
# 95X             595
# 95W            1462
# 95V             329
# 95U            1998
# 95T             888
# 95S            1640
# 95R            1017
# 95Q             294
# ...

# %%
pop['Males']= pop['Males'].astype('int')
pop['Females']= pop['Females'].astype('int')
pop['Lives in a household']= pop['Lives in a household'].astype('int')
pop['Lives in a communal establishment']= pop['Lives in a communal establishment'].astype('int')

# %%
pop.dtypes
# Out:
# population                             int64
# Males                                  int64
# Females                                int64
# Lives in a household                   int64
# Lives in a communal establishment      int64
# Schoolchild                          float64
# Area                                 float64
# Density                              float64
# dtype: object

# %%
finaljoined=finaljoined.set_index('ladcd')
finaljoined.head(4)
# Out:
#             latitude  longitude     oa11cd   lsoa11cd   msoa11cd  \
# ladcd
# S12000033  57.144165  -2.114848  S00088970  S01006571  S02001247
# S12000033  57.137880  -2.121487  S00089205  S01006576  S02001248
# S12000033  57.124274  -2.127190  S00089357  S01006530  S02001239
# S12000033  57.142701  -2.093295  S00090582  S01006587  S02001250
#
#                         lsoa11nm          msoa11nm          ladnm     FID
# ladcd
# S12000033    West End North - 01    West End North  Aberdeen City  3015.0
# S12000033    West End South - 02    West End South  Aberdeen City  3146.0
# S12000033          Garthdee - 05          Garthdee  Aberdeen City  3489.0
# S12000033  City Centre East - 01  City Centre East  Aberdeen City  3876.0

# %%
data=pd.read_csv('Postcode_coordinates.csv')

# %%
data.head(2)
# Out:
#    postcode   latitude  longitude     oa11cd   lsoa11cd   msoa11cd      ladcd  \
# 0  AB10 1XG  57.144165  -2.114848  S00088970  S01006571  S02001247  S12000033
# 1  AB10 6RN  57.137880  -2.121487  S00089205  S01006576  S02001248  S12000033
#
#               lsoa11nm        msoa11nm          ladnm     FID
# 0  West End North - 01  West End North  Aberdeen City  3015.0
# 1  West End South - 02  West End South  Aberdeen City  3146.0

# %%
data=data.set_index('ladcd')
data.head(4)
# Out:
#            postcode   latitude  longitude     oa11cd   lsoa11cd   msoa11cd  \
# ladcd
# S12000033  AB10 1XG  57.144165  -2.114848  S00088970  S01006571  S02001247
# S12000033  AB10 6RN  57.137880  -2.121487  S00089205  S01006576  S02001248
# S12000033  AB10 7JB  57.124274  -2.127190  S00089357  S01006530  S02001239
# S12000033  AB11 5QN  57.142701  -2.093295  S00090582  S01006587  S02001250
#
#                         lsoa11nm          msoa11nm          ladnm     FID
# ladcd
# S12000033    West End North - 01    West End North  Aberdeen City  3015.0
# S12000033    West End South - 02    West End South  Aberdeen City  3146.0
# S12000033          Garthdee - 05          Garthdee  Aberdeen City  3489.0
# S12000033  City Centre East - 01  City Centre East  Aberdeen City  3876.0

# %%
#merged = a.merge(b, on='ID')
result = pop.join(data)

# %%
result.head(4)
# Out:
#       population  Males  Females  Lives in a household  \
# 95A       107877  52648    55229                106500
# 95B        33536  16927    16609                 32850
# 95C        59067  28742    30325                 57761
# 95D        31224  15442    15782                 31054
#
#       Lives in a communal establishment  Schoolchild     Area   Density  \
# 95A                                1377        1560.0  37947.0      2.8
# 95B                                 686         415.0  58526.0      0.6
# 95C                                1306         858.0  48299.0      1.2
# 95D                                 170         374.0  41782.0      0.8
#
#      postcode  latitude  longitude oa11cd lsoa11cd msoa11cd lsoa11nm msoa11nm  \
# 95A       NaN       NaN        NaN    NaN      NaN      NaN      NaN      NaN
# 95B       NaN       NaN        NaN    NaN      NaN      NaN      NaN      NaN
# 95C       NaN       NaN        NaN    NaN      NaN      NaN      NaN      NaN
# ...

# %%
result.shape
# Out:
# (1642503, 18)

# %%
result.isna()
# Out:
#            population  Males  Females  Lives in a household  \
# 95A             False  False    False                 False
# 95B             False  False    False                 False
# 95C             False  False    False                 False
# 95D             False  False    False                 False
# 95E             False  False    False                 False
# 95F             False  False    False                 False
# 95G             False  False    False                 False
# 95H             False  False    False                 False
# 95I             False  False    False                 False
# 95J             False  False    False                 False
# 95K             False  False    False                 False
# 95L             False  False    False                 False
# 95M             False  False    False                 False
# 95N             False  False    False                 False
# 95O             False  False    False                 False
# ...

# %%
resultpop=result.dropna()

# %%
resultpop.head(2)
# Out:
#            population  Males  Females  Lives in a household  \
# E06000001       92028  44751    47277                 91091
# E06000001       92028  44751    47277                 91091
#
#            Lives in a communal establishment  Schoolchild    Area   Density  \
# E06000001                                937         780.0  9386.0      9.8
# E06000001                                937         780.0  9386.0      9.8
#
#            postcode   latitude  longitude     oa11cd   lsoa11cd   msoa11cd  \
# E06000001  TS27 4SX  54.681570  -1.210380  E00060531  E01011999  E02002489
# E06000001  TS27 3AR  54.710559  -1.273018  E00060316  E01011959  E02006909
#
#                   lsoa11nm        msoa11nm       ladnm        FID
# E06000001  Hartlepool 007D  Hartlepool 007  Hartlepool  2388382.0
# E06000001  Hartlepool 014A  Hartlepool 014  Hartlepool  2387696.0

# %%
resultpop.to_csv('population_postcode.csv',index=True)

# %%
urban = pd.read_csv('/Users/jyothigupta/Documents/UCL/Urbansimulation/week5/data/popincome.csv', na_values='')
urban.head(3)
# Out:
#         code                 label     pop  avg_income  med_income
# 0  E09000001        City of London   12000       92900       38300
# 1  E09000002  Barking and Dagenham   56000       18600       16200
# 2  E09000003                Barnet  159000       30400       18700

# %%
urban.shape
# Out:
# (33, 5)

# %%
SICdata.head(2)
# Out:
#   incorporationdate  postcode          companycategory companystatus  \
# 0        1992-05-12   SE4 1NQ  Private Limited Company        Active
# 1        1999-07-22  TN11 9PL  Private Limited Company        Active
#
#            CompanyCategory CompanyStatus IncorporationDate  SIC_2013  SIC2018  \
# 0  Private Limited Company        Active        12/05/1992     90010    90010
# 1  Private Limited Company        Active        22/07/1999     70229    70229
#
#    SICcombine
# 0     90010.0
# 1     70229.0

# %%
SICpost=SICdata.set_index('postcode')
SICpost.head(4)
# Out:
#          incorporationdate          companycategory companystatus  \
# postcode
# SE4 1NQ         1992-05-12  Private Limited Company        Active
# TN11 9PL        1999-07-22  Private Limited Company        Active
# GU21 5TS        2007-11-28  Private Limited Company        Active
# WD6 1JD         2008-01-15  Private Limited Company        Active
#
#                   CompanyCategory CompanyStatus IncorporationDate  SIC_2013  \
# postcode
# SE4 1NQ   Private Limited Company        Active        12/05/1992     90010
# TN11 9PL  Private Limited Company        Active        22/07/1999     70229
# GU21 5TS  Private Limited Company        Active        28/11/2007     99999
# WD6 1JD   Private Limited Company        Active        15/01/2008     56101
#
#           SIC2018  SICcombine
# postcode
# SE4 1NQ     90010     90010.0
# TN11 9PL    70229     70229.0
# GU21 5TS    99999     99999.0
# WD6 1JD     56101     56101.0

# %%
resultpost=resultpop.set_index('postcode')
resultpost.head(4)
# Out:
#           population  Males  Females  Lives in a household  \
# postcode
# TS27 4SX       92028  44751    47277                 91091
# TS27 3AR       92028  44751    47277                 91091
# TS27 3AS       92028  44751    47277                 91091
# TS27 3AT       92028  44751    47277                 91091
#
#           Lives in a communal establishment  Schoolchild    Area   Density  \
# postcode
# TS27 4SX                                937         780.0  9386.0      9.8
# TS27 3AR                                937         780.0  9386.0      9.8
# TS27 3AS                                937         780.0  9386.0      9.8
# TS27 3AT                                937         780.0  9386.0      9.8
#
#            latitude  longitude     oa11cd   lsoa11cd   msoa11cd  \
# postcode
# TS27 4SX  54.681570  -1.210380  E00060531  E01011999  E02002489
# TS27 3AR  54.710559  -1.273018  E00060316  E01011959  E02006909
# TS27 3AS  54.709460  -1.274327  E00060315  E01011959  E02006909
# ...

# %%
SICpost.shape
# Out:
# (1148256, 9)

# %%
resultpost.shape
# Out:
# (1642413, 17)

# %%
complete = SICpost.join(resultpost)

# %%
complete.shape
# Out:
# (1148256, 26)

# %%
complete.head()
# Out:
#          incorporationdate      companycategory companystatus  \
# postcode
# 06 830          2008-05-28  Limited Partnership        Active
# 06 830          2008-05-28  Limited Partnership        Active
# 06 830          2008-05-28  Limited Partnership        Active
# 06 830          2008-05-28  Limited Partnership        Active
# 06 830          2008-05-28  Limited Partnership        Active
#
#               CompanyCategory CompanyStatus IncorporationDate  SIC_2013  \
# postcode
# 06 830    Limited Partnership        Active        28/05/2008         0
# 06 830    Limited Partnership        Active        28/05/2008         0
# 06 830    Limited Partnership        Active        28/05/2008         0
# 06 830    Limited Partnership        Active        28/05/2008         0
# 06 830    Limited Partnership        Active        28/05/2008         0
#
#           SIC2018  SICcombine  population  ...  Density  latitude  longitude  \
# postcode                                   ...
# ...

# %%
comp=complete.dropna()

# %%
comp.head(2)
# Out:
#          incorporationdate                                    companycategory  \
# postcode
# AB10 1BA        2008-12-08  PRI/LTD BY GUAR/NSC (Private, limited by guara...
# AB10 1BA        2006-06-13                            Private Limited Company
#
#          companystatus                                    CompanyCategory  \
# postcode
# AB10 1BA        Active  PRI/LTD BY GUAR/NSC (Private, limited by guara...
# AB10 1BA        Active                            Private Limited Company
#
#          CompanyStatus IncorporationDate  SIC_2013  SIC2018  SICcombine  \
# postcode
# AB10 1BA        Active        08/12/2008     82990    82990     82990.0
# AB10 1BA        Active        13/06/2006     58142    58142     58142.0
#
#           population  ...  Density   latitude  longitude     oa11cd  \
# postcode              ...
# AB10 1BA    222793.0  ...     12.0  57.148832  -2.098451  S00090540
# AB10 1BA    222793.0  ...     12.0  57.148832  -2.098451  S00090540
#
# ...

# %%
comp.dtypes
# Out:
# incorporationdate                     object
# companycategory                       object
# companystatus                         object
# CompanyCategory                       object
# CompanyStatus                         object
# IncorporationDate                     object
# SIC_2013                               int64
# SIC2018                                int64
# SICcombine                           float64
# population                           float64
# Males                                float64
# Females                              float64
# Lives in a household                 float64
# Lives in a communal establishment    float64
# Schoolchild                          float64
# Area                                 float64
# Density                              float64
# latitude                             float64
# longitude                            float64
# oa11cd                                object
# lsoa11cd                              object
# ...

# %%
comp['population']= comp['population'].astype('int')
comp['SICcombine']= comp['SICcombine'].astype('int')
comp['Males']= comp['Males'].astype('int')
comp['Females']= comp['Females'].astype('int')
# Out:
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/jyothigupta/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
comp.dtypes
# Out:
# incorporationdate                     object
# companycategory                       object
# companystatus                         object
# CompanyCategory                       object
# CompanyStatus                         object
# IncorporationDate                     object
# SIC_2013                               int64
# SIC2018                                int64
# SICcombine                             int64
# population                             int64
# Males                                  int64
# Females                                int64
# Lives in a household                 float64
# Lives in a communal establishment    float64
# Schoolchild                          float64
# Area                                 float64
# Density                              float64
# latitude                             float64
# longitude                            float64
# oa11cd                                object
# lsoa11cd                              object
# ...

# %%
comp.to_csv('complete.csv',index=True)
