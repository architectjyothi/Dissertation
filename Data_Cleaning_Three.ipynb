# %%
import csv
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Final.csv', na_values='')

# %%
data.head()
# Out:
#   incorporationdate  postcode          companycategory companystatus  \
# 0        1992-05-12   SE4 1NQ  Private Limited Company        Active
# 1        1999-07-22  TN11 9PL  Private Limited Company        Active
# 2        2007-11-28  GU21 5TS  Private Limited Company        Active
# 3        2008-01-15   WD6 1JD  Private Limited Company        Active
# 4        2002-07-25   OL2 7DD  Private Limited Company        Active
#
#            CompanyCategory CompanyStatus IncorporationDate  SIC_2013 SIC2018  \
# 0  Private Limited Company        Active        12/05/1992     90010   90010
# 1  Private Limited Company        Active        22/07/1999     70229   70229
# 2  Private Limited Company        Active        28/11/2007     99999   99999
# 3  Private Limited Company        Active        15/01/2008     56101   56101
# 4  Private Limited Company        Active        25/07/2002     86230   86230
#
#    SICcombine
# 0     90010.0
# 1     70229.0
# 2     99999.0
# 3     56101.0
# ...

# %%
# Digital technologies
sic_digital = [26110,26120,26200,26400,26511,26512,26800,33130,
                58210,58290,62011,62012,62020,62030,62090,63110,
                63120,95110]
# Life Sciences and healthcare
sic_science = [21100,21200,26600,26701,32500,72110,75000,86101,
                86102,86210,86220,86230,86900]
# Publishing and broadcasting
sic_publishing = [26301,26309,26702,58110,58120,58130,58141,58142,
                   58190,59111,59112,59113,59120,59131,59132,59133,
                   59140,59200,60100,60200,61100,61200, 61300,61900,
                   63910,63990,73110,73120,73200,74100,74201,74202,
                   74203,74209,95120]
# Other scientific activities of manufacturing
sic_otherScManuf = [19201,19209,20110,20120,20130,95210,95220,95250,
                     20140,20150,20160,20170,20200,20301,20302,20411,
                     20412,20420,20510,20520,20530,20590,20600,25210,
                     25300,25400,26513,26514,26520,27110,27120,27200,
                     27310,27320,27330,27400,27510,27520,27900,28110,
                     28120,28131,28132,28140,28150,28210,28220,28230,
                     28240,28250,28290,28301,28302,28410,28490,28910,
                     28921,28922,28923,28930,28940,28950,28960,28990,
                     29100,29201,29202,29203,29310,29320,30110,30120,
                     30200,30300,30400,30910,30920,30990,32120,32401,
                     33120,33140,33150,33160,33170]
# Other scientific activity services
sic_otherScServices = [51101,51102,51210,51220,71111,71112,71121,71122,
                        71129,71200,72190,72200,74901,74902,85410,85421,
                        85422]
# Food and accomodation
sic_food = [55100,55201,55202,55209,55300, 56101,56102,56103,
             56210,56290,56301,56302]
# Entertainment
sic_entertainment = [59140, 82301,82302, 90010,91011,91012,91020,91030,
                      91040,92000,93110, 93120,93130,93191,93199, 93020]
# Retail except retail trade of motor vehicles
sic_retail = [47190,47990,47290,47789,47782,47810,47890,47820,
               47781,47110,47791,47430,47300,47250,47610,47240,
               47530,47710,47410,47750,47540,47230,47760,47721,
               47210,47599,47650,47520,47741,47722,47220,47749,
               47421,47630,47591,47620,47799,47640,47429,47510,
               47260,47770,47910]

# %%
data.loc[data.SIC_2013 == 21100]
# Out:
#         incorporationdate  postcode          companycategory companystatus  \
# 1150           2010-02-10  TR11 5JP  Private Limited Company        Active
# 24501          1930-08-01  SW19 5LP  Private Limited Company        Active
# 32988          2009-11-10   SL6 4XE  Private Limited Company        Active
# 32989          2009-11-10   SL6 4XE  Private Limited Company        Active
# 33011          2001-10-16   SL6 4XE  Private Limited Company        Active
# 35608          1981-09-02    L7 2PG  Private Limited Company        Active
# 40534          1998-11-03   W1U 7GB  Private Limited Company        Active
# 40536          2011-03-15   HD8 9SH  Private Limited Company        Active
# 45044          1998-05-15   CW7 3RT  Private Limited Company        Active
# 45161          1998-07-23   CW7 3RT  Private Limited Company        Active
# 45164          1991-11-29   CW7 3RT  Private Limited Company        Active
# ...

# %%
data.loc[data.SIC_2013 >= 47910]
#df.loc[df.Price >= 10]
# Out:
#         incorporationdate  postcode  \
# 0              1992-05-12   SE4 1NQ
# 1              1999-07-22  TN11 9PL
# 2              2007-11-28  GU21 5TS
# 3              2008-01-15   WD6 1JD
# 4              2002-07-25   OL2 7DD
# 5              2005-12-12   HA2 6AU
# 6              1984-01-19  WC2B 6QX
# 7              2004-12-21  LE12 7TZ
# 9              1993-11-12   W12 8LA
# 10             1978-08-07   NR2 2AL
# 11             2002-04-30  PE30 1LT
# 12             1927-11-26  DT11 0PX
# 14             1986-11-21   NW3 1EH
# 15             1899-07-27    N6 5HF
# 17             2004-08-20   NW7 2DQ
# 19             1984-03-07   WF8 4BG
# 20             1985-10-02   TQ1 3NT
# 22             1965-06-14   BR3 5BZ
# 23             2009-03-02   B18 6EW
# 24             1998-07-29   IG1 1BA
# 25             1992-01-31  PO30 1JW
# 28             1927-12-22  CT12 6RR
# 29             1988-11-17  TW14 0SL
# 30             1984-10-03  BS10 6LW
# 31             1983-06-14   BB4 7HB
# ...

# %%
data.dtypes
# Out:
# incorporationdate     object
# postcode              object
# companycategory       object
# companystatus         object
# CompanyCategory       object
# CompanyStatus         object
# IncorporationDate     object
# SIC_2013               int64
# SIC2018               object
# SICcombine           float64
# dtype: object

# %%
data["SIC2018"]= data["SIC2018"].replace('None Supplied',0)

# %%
data
# Out:
#         incorporationdate  postcode  \
# 0              1992-05-12   SE4 1NQ
# 1              1999-07-22  TN11 9PL
# 2              2007-11-28  GU21 5TS
# 3              2008-01-15   WD6 1JD
# 4              2002-07-25   OL2 7DD
# 5              2005-12-12   HA2 6AU
# 6              1984-01-19  WC2B 6QX
# 7              2004-12-21  LE12 7TZ
# 8              1964-06-03   SM7 2NL
# 9              1993-11-12   W12 8LA
# 10             1978-08-07   NR2 2AL
# 11             2002-04-30  PE30 1LT
# 12             1927-11-26  DT11 0PX
# 13             1998-12-21  LS22 6SN
# 14             1986-11-21   NW3 1EH
# 15             1899-07-27    N6 5HF
# 16             2006-05-16  BT78 1LE
# 17             2004-08-20   NW7 2DQ
# 18             1996-12-19   SG6 9BL
# 19             1984-03-07   WF8 4BG
# 20             1985-10-02   TQ1 3NT
# 21             1998-07-03  BT82 8DX
# 22             1965-06-14   BR3 5BZ
# 23             2009-03-02   B18 6EW
# 24             1998-07-29   IG1 1BA
# ...

# %%
data["SIC2018"] = pd.to_numeric(data["SIC2018"])

# %%
data.dtypes
# Out:
# incorporationdate     object
# postcode              object
# companycategory       object
# companystatus         object
# CompanyCategory       object
# CompanyStatus         object
# IncorporationDate     object
# SIC_2013               int64
# SIC2018                int64
# SICcombine           float64
# dtype: object

# %%
data.to_csv('SIC_integer.csv',index=False)

# %%
data.SIC2018 == 21100
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1148226    False
# 1148227    False
# 1148228    False
# 1148229    False
# 1148230    False
# 1148231    False
# 1148232    False
# 1148233    False
# 1148234    False
# 1148235    False
# 1148236    False
# 1148237    False
# 1148238    False
# 1148239    False
# 1148240    False
# 1148241    False
# 1148242    False
# 1148243    False
# 1148244    False
# 1148245    False
# 1148246    False
# ...

# %%
data.loc[data.SIC2018 >= 47910]
# Out:
#         incorporationdate  postcode  \
# 0              1992-05-12   SE4 1NQ
# 1              1999-07-22  TN11 9PL
# 2              2007-11-28  GU21 5TS
# 3              2008-01-15   WD6 1JD
# 4              2002-07-25   OL2 7DD
# 5              2005-12-12   HA2 6AU
# 9              1993-11-12   W12 8LA
# 10             1978-08-07   NR2 2AL
# 11             2002-04-30  PE30 1LT
# 12             1927-11-26  DT11 0PX
# 14             1986-11-21   NW3 1EH
# 15             1899-07-27    N6 5HF
# 17             2004-08-20   NW7 2DQ
# 19             1984-03-07   WF8 4BG
# 20             1985-10-02   TQ1 3NT
# 22             1965-06-14   BR3 5BZ
# 23             2009-03-02   B18 6EW
# 24             1998-07-29   IG1 1BA
# 25             1992-01-31  PO30 1JW
# 28             1927-12-22  CT12 6RR
# 29             1988-11-17  TW14 0SL
# 30             1984-10-03  BS10 6LW
# 31             1983-06-14   BB4 7HB
# 32             1984-05-04   RH9 8DR
# 34             1989-07-25   N20 9HR
# ...

# %%
# ?sort
# Out:
# Object `sort` not found.

# %%
startup = data.sort_values(by=['incorporationdate','IncorporationDate'])

# %%
startup['IncorporationDate'] = pd.to_datetime(startup['IncorporationDate'])
#['incorporationdate','IncorporationDate']

# %%
startup['incorporationdate'] = pd.to_datetime(startup['incorporationdate'])
#['incorporationdate','IncorporationDate']

# %%
start_date_1 = '2009-01-03'
end_date_1='2013-12-29'
mask_1 = (startup['incorporationdate'] > start_date_1) & (startup['incorporationdate'] <= end_date_1)

# %%
startup2013= startup.loc[mask_1]
startup2013
# Out:
#         incorporationdate  postcode  \
# 5786           2009-01-05   RG1 2QU
# 20773          2009-01-05  SW17 7PY
# 33184          2009-01-05  DE55 7HH
# 35227          2009-01-05   SL7 3DF
# 50821          2009-01-05    G1 4AG
# 61087          2009-01-05  SW1W 9QQ
# 64347          2009-01-05   N21 3NA
# 66813          2009-01-05   BB9 7AW
# 79959          2009-01-05   SK6 5DW
# 85513          2009-01-05   N12 8RT
# 86386          2009-01-05   HA9 8HB
# 86742          2009-01-05   HA9 8HA
# 92956          2009-01-05  WC2A 3PE
# 93229          2009-01-05   WV1 4EG
# 93604          2009-01-05   BR7 6BY
# 94432          2009-01-05   HA8 6PG
# 97668          2009-01-05  EC1A 9ET
# 108835         2009-01-05  TN12 5AZ
# 114327         2009-01-05   RH8 0ND
# 116622         2009-01-05   CM6 1AE
# 130328         2009-01-05   LE8 6ZG
# 131699         2009-01-05   HP2 7SS
# 132363         2009-01-05   RG7 8NN
# 133910         2009-01-05   RH2 8JX
# 133946         2009-01-05   N12 0DR
# ...

# %%
startup2013.to_csv('startup2013.csv',index=False)

# %%
start_date = '2013-01-03'
end_date='2018-12-29'

# %%
mask = (startup['IncorporationDate'] > start_date) & (startup['IncorporationDate'] <= end_date)

# %%
startup['IncorporationDate'] <= end_date
# Out:
# 1146480    True
# 87441      True
# 156426     True
# 661249     True
# 1144767    True
# 106053     True
# 822244     True
# 940959     True
# 877809     True
# 1032014    True
# 876732     True
# 586797     True
# 890768     True
# 439019     True
# 537606     True
# 631193     True
# 638366     True
# 156427     True
# 148985     True
# 662971     True
# 793476     True
# 726070     True
# 665075     True
# 1145297    True
# 793339     True
# 453763     True
# 206985     True
# 579224     True
# 534557     True
# 964863     True
#            ...
# 1142073    True
# 1142096    True
# 1142105    True
# 1142112    True
# 1142137    True
# 1142208    True
# 1142220    True
# 1142272    True
# 1142279    True
# 1142283    True
# 1142314    True
# 1142322    True
# 1142329    True
# 1142345    True
# 1142392    True
# 1142413    True
# 1142425    True
# 1142457    True
# 1142473    True
# 1142503    True
# 1142528    True
# 1142534    True
# 1142557    True
# 1142601    True
# ...

# %%
mask
# Out:
# 1146480    False
# 87441      False
# 156426     False
# 661249     False
# 1144767    False
# 106053     False
# 822244     False
# 940959     False
# 877809     False
# 1032014    False
# 876732     False
# 586797     False
# 890768     False
# 439019     False
# 537606     False
# 631193     False
# 638366     False
# 156427     False
# 148985     False
# 662971     False
# 793476     False
# 726070     False
# 665075     False
# 1145297    False
# 793339     False
# 453763     False
# 206985     False
# 579224     False
# 534557     False
# 964863     False
#            ...
# 1142073    False
# 1142096    False
# 1142105    False
# 1142112    False
# 1142137    False
# 1142208    False
# 1142220    False
# 1142272    False
# 1142279    False
# 1142283    False
# 1142314    False
# 1142322    False
# 1142329    False
# 1142345    False
# 1142392    False
# 1142413    False
# 1142425    False
# 1142457    False
# 1142473    False
# 1142503    False
# 1142528    False
# ...

# %%
(startup['IncorporationDate'] > start_date)
# Out:
# 1146480    False
# 87441      False
# 156426     False
# 661249     False
# 1144767    False
# 106053     False
# 822244     False
# 940959     False
# 877809     False
# 1032014    False
# 876732     False
# 586797     False
# 890768     False
# 439019     False
# 537606     False
# 631193     False
# 638366     False
# 156427     False
# 148985     False
# 662971     False
# 793476     False
# 726070     False
# 665075     False
# 1145297    False
# 793339     False
# 453763     False
# 206985     False
# 579224     False
# 534557     False
# 964863     False
#            ...
# 1142073    False
# 1142096    False
# 1142105    False
# 1142112    False
# 1142137    False
# 1142208    False
# 1142220    False
# 1142272    False
# 1142279    False
# 1142283    False
# 1142314    False
# 1142322    False
# 1142329    False
# 1142345    False
# 1142392    False
# 1142413    False
# 1142425    False
# 1142457    False
# 1142473    False
# 1142503    False
# 1142528    False
# ...

# %%
startup['IncorporationDate']
# Out:
# 1146480   1832-05-23
# 87441     1856-09-25
# 156426    1856-09-29
# 661249    1856-09-30
# 1144767   1856-10-23
# 106053    1856-04-11
# 822244    1859-02-17
# 940959    1860-03-29
# 877809    1860-08-14
# 1032014   1861-01-23
# 876732    1861-10-09
# 586797    1862-08-08
# 890768    1862-10-15
# 439019    1862-01-11
# 537606    1862-11-27
# 631193    1863-03-13
# 638366    1863-05-19
# 156427    1863-10-10
# 148985    1863-10-12
# 662971    1864-06-14
# 793476    1864-06-20
# 726070    1864-11-07
# 665075    1864-07-25
# 1145297   1864-08-27
# 793339    1864-11-19
# 453763    1865-11-03
# 206985    1865-03-20
# 579224    1865-04-20
# 534557    1865-08-14
# 964863    1865-08-29
#              ...
# 1142073   2013-03-28
# 1142096   2013-03-28
# 1142105   2013-03-28
# 1142112   2013-03-28
# 1142137   2013-03-28
# 1142208   2013-03-28
# 1142220   2013-03-28
# 1142272   2013-03-28
# 1142279   2013-03-28
# 1142283   2013-03-28
# 1142314   2013-03-28
# 1142322   2013-03-28
# ...

# %%
mask.dtypes
# Out:
# dtype('bool')

# %%
startup2018= startup.loc[mask]
startup2018
# Out:
#         incorporationdate  postcode  \
# 1114082        2013-01-02   SA1 3EZ
# 1114142        2013-01-02   N12 0DR
# 1114183        2013-01-02   S36 1GA
# 1114185        2013-01-02   PE2 6PZ
# 1114240        2013-01-02  CH64 4BA
# 1114245        2013-01-02   LE7 7JU
# 1114251        2013-01-02    N3 1AR
# 1114282        2013-01-02  NG18 3EG
# 1114297        2013-01-02   B75 5ET
# 1114307        2013-01-02   HG3 2SY
# 1114316        2013-01-02   CB8 8FE
# 1114373        2013-01-02   EX1 2BJ
# 1114390        2013-01-02  LS10 2RU
# 1114403        2013-01-02   W14 9AP
# 1114420        2013-01-02   LE1 7EA
# 1114431        2013-01-02   N10 3AG
# 1114435        2013-01-02   AL3 4NG
# 1114458        2013-01-02   IG1 1TE
# 1114481        2013-01-02  GU30 7AZ
# 1114493        2013-01-02   DN6 8DA
# 1114498        2013-01-02   NN7 1BA
# 1114547        2013-01-02  LS28 6QB
# 1114598        2013-01-02   NR1 3PL
# 1114599        2013-01-02   W11 1AP
# 1114601        2013-01-02  TR11 4AB
# ...

# %%
#this will add column for company status in 2013 startup
startup['company2013'] = np.where(startup['companystatus']=='Active','Active','NotActive')

# %%
#this will add column for company status in 2018 startup
startup['company2018'] = np.where(startup['CompanyStatus']=='Active','Active','NotActive')

# %%
startup2018.to_csv('startup2018.csv',index=False)

# %%
startup.head()
# Out:
#         incorporationdate  postcode          companycategory companystatus  \
# 1146480        1832-05-23  LL49 9NF       Other company type        Active
# 87441          1856-09-25  TN23 1DA  Private Limited Company        Active
# 156426         1856-09-29  SW1E 5JQ  Private Limited Company        Active
# 661249         1856-09-30   RM8 1SP  Private Limited Company        Active
# 1144767        1856-10-23  RG12 1AN  Private Limited Company        Active
#
#                  CompanyCategory CompanyStatus IncorporationDate  SIC_2013  \
# 1146480       Other company type        Active        23/05/1832         0
# 87441    Private Limited Company        Active        25/09/1856     46110
# 156426   Private Limited Company        Active        29/09/1856     50200
# 661249   Private Limited Company        Active        30/09/1856     46730
# 1144767  Private Limited Company        Active        23/10/1856         0
#
#          SIC2018  SICcombine
# 1146480    47190         NaN
# ...

# %%
data.index.argsort()
# Out:
# array([      0,       1,       2, ..., 1148253, 1148254, 1148255])

# %%
import operator
sort = sorted(data,key=operator.itemgetter(3),reverse=True)

# %%
sort
# Out:
# ['postcode',
#  'companycategory',
#  'companystatus',
#  'CompanyCategory',
#  'CompanyStatus',
#  'incorporationdate',
#  'IncorporationDate',
#  'SICcombine',
#  'SIC_2013',
#  'SIC2018']

# %%
from random import choice
print(choice(sic_retail))
# Out:
# 47220

# %%
from random import randrange
test = randrange(3,len(sic_retail))
print(sic_retail[test])
# Out:
# 47722

# %%
sample = ''.join(str(n) for n in sic_retail)
print(sample)
# Out:
# 47190479904729047789477824781047890478204778147110477914743047300472504761047240475304771047410477504754047230477604772147210475994765047520477414772247220477494742147630475914762047799476404742947510472604777047910

# %%
list(zip(sic_retail))
# Out:
# [(47190,),
#  (47990,),
#  (47290,),
#  (47789,),
#  (47782,),
#  (47810,),
#  (47890,),
#  (47820,),
#  (47781,),
#  (47110,),
#  (47791,),
#  (47430,),
#  (47300,),
#  (47250,),
#  (47610,),
#  (47240,),
#  (47530,),
#  (47710,),
#  (47410,),
#  (47750,),
#  (47540,),
#  (47230,),
#  (47760,),
#  (47721,),
#  (47210,),
#  (47599,),
#  (47650,),
#  (47520,),
#  (47741,),
#  (47722,),
#  (47220,),
#  (47749,),
#  (47421,),
#  (47630,),
#  (47591,),
#  (47620,),
#  (47799,),
#  (47640,),
#  (47429,),
#  (47510,),
#  (47260,),
#  (47770,),
#  (47910,)]

# %%
len(sic_retail)
# Out:
# 43

# %%
len(data)
# Out:
# 1148256

# %%
sic_retail.__iter__
# Out:
# <method-wrapper '__iter__' of list object at 0x121f88948>

# %%
data.__iter__
# Out:
# <bound method NDFrame.__iter__ of         incorporationdate  postcode  \
# 0              1992-05-12   SE4 1NQ
# 1              1999-07-22  TN11 9PL
# 2              2007-11-28  GU21 5TS
# 3              2008-01-15   WD6 1JD
# 4              2002-07-25   OL2 7DD
# 5              2005-12-12   HA2 6AU
# 6              1984-01-19  WC2B 6QX
# 7              2004-12-21  LE12 7TZ
# 8              1964-06-03   SM7 2NL
# 9              1993-11-12   W12 8LA
# 10             1978-08-07   NR2 2AL
# 11             2002-04-30  PE30 1LT
# 12             1927-11-26  DT11 0PX
# 13             1998-12-21  LS22 6SN
# 14             1986-11-21   NW3 1EH
# 15             1899-07-27    N6 5HF
# 16             2006-05-16  BT78 1LE
# 17             2004-08-20   NW7 2DQ
# 18             1996-12-19   SG6 9BL
# 19             1984-03-07   WF8 4BG
# 20             1985-10-02   TQ1 3NT
# 21             1998-07-03  BT82 8DX
# 22             1965-06-14   BR3 5BZ
# 23             2009-03-02   B18 6EW
# ...

# %%
intersection = [list(filter(lambda x: x in sic_retail, sublist)) for sublist in startup]
print(intersection)
# Out:
# [[], [], [], [], [], [], [], [], [], []]

# %%
startup.dtypes
# Out:
# incorporationdate    datetime64[ns]
# postcode                     object
# companycategory              object
# companystatus                object
# CompanyCategory              object
# CompanyStatus                object
# IncorporationDate    datetime64[ns]
# SIC_2013                      int64
# SIC2018                       int64
# SICcombine                  float64
# company2013                  object
# company2018                  object
# dtype: object

# %%
data.dtypes
# Out:
# incorporationdate     object
# postcode              object
# companycategory       object
# companystatus         object
# CompanyCategory       object
# CompanyStatus         object
# IncorporationDate     object
# SIC_2013               int64
# SIC2018                int64
# SICcombine           float64
# dtype: object

# %%
sicdata13.dtypes
# Out:
# incorporationdate     object
# postcode              object
# companycategory       object
# companystatus         object
# CompanyCategory       object
# CompanyStatus         object
# IncorporationDate     object
# SIC2018                int64
# SICcombine           float64
# company2013           object
# company2018           object
# dtype: object

# %%
KBI = startup.sort_values(by=['SIC_2013','SIC2018'])

# %%
KBI.head()
# Out:
#         incorporationdate postcode          companycategory companystatus  \
# 793339         1864-11-19  HX3 7PA  Private Limited Company        Active
# 453763         1865-03-11  GL6 0RG  Private Limited Company   Liquidation
# 1148157        1875-01-01  XXXXXXX  Private Limited Company   Liquidation
# 1143892        1877-06-18  PE2 8BQ  Private Limited Company        Active
# 1145149        1883-04-15  M60 8BH  Private Limited Company        Active
#
#                  CompanyCategory CompanyStatus IncorporationDate  SIC_2013  \
# 793339   Private Limited Company   Liquidation        1864-11-19         0
# 453763   Private Limited Company   Liquidation        1865-11-03         0
# 1148157  Private Limited Company   Liquidation        1875-01-01         0
# 1143892  Private Limited Company        Active        1877-06-18         0
# 1145149  Private Limited Company   Liquidation        1883-04-15         0
#
#          SIC2018  SICcombine company2013 company2018
# ...

# %%
sicdata13= startup2013.set_index('SIC_2013')

# %%
sicdata13=startup2013.drop(['companycategory','companystatus',
                             'CompanyCategory','CompanyStatus',
                             'SICcombine','IncorporationDate'],axis=1)

# %%
startup2013.head(3)
# Out:
#       incorporationdate  postcode          companycategory companystatus  \
# 5786         2009-01-05   RG1 2QU  Private Limited Company        Active
# 20773        2009-01-05  SW17 7PY  Private Limited Company        Active
# 33184        2009-01-05  DE55 7HH  Private Limited Company        Active
#
#                CompanyCategory CompanyStatus IncorporationDate  SIC_2013  \
# 5786   Private Limited Company        Active        2009-05-01     45200
# 20773  Private Limited Company        Active        2009-05-01     62020
# 33184  Private Limited Company        Active        2009-05-01     84250
#
#        SIC2018  SICcombine company2013 company2018
# 5786     45200     45200.0      Active      Active
# 20773    62020     62020.0      Active      Active
# 33184    84250     84250.0      Active      Active

# %%
sicdata13= sicdata13.set_index('SIC_2013')

# %%
sicdata13.head(4)
# Out:
#          incorporationdate  postcode  SIC2018 company2013 company2018
# SIC_2013
# 45200           2009-01-05   RG1 2QU    45200      Active      Active
# 62020           2009-01-05  SW17 7PY    62020      Active      Active
# 84250           2009-01-05  DE55 7HH    84250      Active      Active
# 56102           2009-01-05   SL7 3DF    56102      Active      Active

# %%
sicdata13
# Out:
#          incorporationdate  postcode  SIC2018 company2013 company2018
# SIC_2013
# 45200           2009-01-05   RG1 2QU    45200      Active      Active
# 62020           2009-01-05  SW17 7PY    62020      Active      Active
# 84250           2009-01-05  DE55 7HH    84250      Active      Active
# 56102           2009-01-05   SL7 3DF    56102      Active      Active
# 93199           2009-01-05    G1 4AG    93199      Active   NotActive
# 99999           2009-01-05  SW1W 9QQ    99999      Active      Active
# 99999           2009-01-05   N21 3NA    99999      Active      Active
# 59112           2009-01-05   BB9 7AW    59112      Active      Active
# 74100           2009-01-05   SK6 5DW    74100      Active      Active
# 55100           2009-01-05   N12 8RT    55100      Active      Active
# 96090           2009-01-05   HA9 8HB    46180      Active      Active
# 69201           2009-01-05   HA9 8HA    69202      Active      Active
# ...

# %%
sicdata13.to_csv('sicdata13.csv',index=False)

# %%
print(sicdata13.iloc[sic_digital])
# Out:
#          incorporationdate  postcode                   companycategory  \
# SIC_2013
# 43999           2003-03-18  CA10 3AS           Private Limited Company
# 46220           1996-04-12  ME13 8SU           Private Limited Company
# 0               1979-05-31   NR3 1AB           Private Limited Company
# 45200           2000-09-07   CT9 5HF           Private Limited Company
# 42990           2011-09-06   EN8 9BH           Private Limited Company
# 4525            1986-03-26   LS1 4JP           Private Limited Company
# 18129           1957-12-30  CO13 0EP           Private Limited Company
# 96090           2004-05-21   SL9 8HF           Private Limited Company
# 39000           2010-07-08   B43 7QA           Private Limited Company
# 62090           2006-12-28   TW1 3DY           Private Limited Company
# 82990           2011-08-18   ML3 6DA           Private Limited Company
# 64999           2003-05-20   W1J 5FJ           Private Limited Company
# ...

# %%
sicdata13_digital= sicdata13.iloc[sic_digital]
sicdata13_digital.head(2)
# Out:
#          incorporationdate  postcode  SIC2018 company2013 company2018
# SIC_2013
# 96090           2009-05-26  NG10 5EH    96090      Active      Active
# 96090           2009-05-26  AB42 3GL    96090      Active      Active

# %%
sicdata13_digital
# Out:
#          incorporationdate  postcode  SIC2018 company2013 company2018
# SIC_2013
# 96090           2009-05-26  NG10 5EH    96090      Active      Active
# 96090           2009-05-26  AB42 3GL    96090      Active      Active
# 56102           2009-05-27  SE10 9JA    56102      Active      Active
# 99999           2009-05-27   DY8 2HG    99999      Active      Active
# 70229           2009-05-28   B13 9BY    70229      Active      Active
# 33120           2009-05-28  TS17 0RB    33120      Active      Active
# 82990           2009-05-29   WA1 1RG    82990      Active      Active
# 45112           2009-07-03   B45 9DR    45112      Active      Active
# 69201           2009-11-19    N7 6NJ    69201      Active      Active
# 52290           2009-11-19  LE65 2NN    52290      Active      Active
# 46180           2009-12-09  CT12 6SR    46180      Active      Active
# 70229           2009-12-09  GL54 1AF    70229      Active      Active
# ...

# %%
sicdata13_digital.to_csv('sicdata13_digital.csv',index=False)

# %%
sicdata13_science= sicdata13.iloc[sic_science]
sicdata13_science.to_csv('sicdata13_science.csv',index=False)
sicdata13_science.head(2)

# %%
sicdata13_publishing= sicdata13.iloc[sic_publishing]
sicdata13_publishing.to_csv('sicdata13_publishing.csv',index=False)
sicdata13_publishing.head(2)
# Out:
#          incorporationdate postcode  SIC2018 company2013 company2018
# SIC_2013
# 32990           2009-05-27  SM4 4LZ    32990      Active      Active
# 59111           2009-05-27  EN5 5RY    59111      Active      Active

# %%
sicdata13_otherScManuf= sicdata13.iloc[sic_otherScManuf]
sicdata13_otherScManuf.to_csv('sicdata13_otherScManuf.csv',index=False)
sicdata13_otherScManuf.head(2)
# Out:
#          incorporationdate  postcode  SIC2018 company2013 company2018
# SIC_2013
# 61900           2009-04-16   OL4 5TL    61900      Active      Active
# 70221           2009-04-16  RG20 8XD    70221      Active      Active

# %%
sicdata13_otherScServices= sicdata13.iloc[sic_otherScServices]
sicdata13_otherScServices.to_csv('sicdata13_otherScServices.csv',index=False)
sicdata13_otherScServices.head(2)
# Out:
#          incorporationdate  postcode  SIC2018 company2013 company2018
# SIC_2013
# 41100           2009-10-16  PA43 7HL    41100      Active      Active
# 99999           2009-10-16    W3 7DA    99999   NotActive      Active

# %%
sicdata13_food= sicdata13.iloc[sic_food]
sicdata13_food.to_csv('sicdata13_food.csv',index=False)
sicdata13_food.head(2)
# Out:
#          incorporationdate postcode  SIC2018 company2013 company2018
# SIC_2013
# 74990           2009-11-04  TQ7 4PA    74990      Active      Active
# 99999           2009-11-04  OX1 5JF    99999      Active      Active

# %%
sicdata13_entertainment= sicdata13.iloc[sic_entertainment]
sicdata13_entertainment.to_csv('sicdata13_entertainment.csv',index=False)
sicdata13_entertainment.head(2)
# Out:
#          incorporationdate postcode  SIC2018 company2013 company2018
# SIC_2013
# 38320           2009-11-24   B3 1PX    38320      Active      Active
# 43220           2010-03-17  SG6 2TU    43220      Active      Active

# %%
sicdata13_retail= sicdata13.iloc[sic_retail]
sicdata13_retail.to_csv('sicdata13_retail.csv',index=False)
sicdata13_retail.head(2)
# Out:
#          incorporationdate  postcode  SIC2018 company2013 company2018
# SIC_2013
# 93110           2009-09-22   GU2 7XH    93110      Active      Active
# 56102           2009-09-25  TN40 1EZ    56102      Active      Active

# %%
#repeating for 2018 KBI
sicdata18=startup2018.drop(['companycategory','companystatus',
                             'CompanyCategory','CompanyStatus',
                             'SICcombine','incorporationdate'],axis=1)
sicdata18.head(2)
# Out:
#         postcode IncorporationDate  SIC_2013  SIC2018 company2013 company2018
# 1114082  SA1 3EZ        2013-02-01         0    47510      Active      Active
# 1114142  N12 0DR        2013-02-01         0    70229      Active      Active

# %%
#repeating for 2018 KBI without startup
sic18=data.drop(['companycategory','companystatus',
                             'CompanyCategory','CompanyStatus',
                             'SICcombine','incorporationdate'],axis=1)
sic18.head(2)
# Out:
#    postcode IncorporationDate  SIC_2013  SIC2018
# 0   SE4 1NQ        12/05/1992     90010    90010
# 1  TN11 9PL        22/07/1999     70229    70229

# %%
data
# Out:
#         incorporationdate  postcode  \
# 0              1992-05-12   SE4 1NQ
# 1              1999-07-22  TN11 9PL
# 2              2007-11-28  GU21 5TS
# 3              2008-01-15   WD6 1JD
# 4              2002-07-25   OL2 7DD
# 5              2005-12-12   HA2 6AU
# 6              1984-01-19  WC2B 6QX
# 7              2004-12-21  LE12 7TZ
# 8              1964-06-03   SM7 2NL
# 9              1993-11-12   W12 8LA
# 10             1978-08-07   NR2 2AL
# 11             2002-04-30  PE30 1LT
# 12             1927-11-26  DT11 0PX
# 13             1998-12-21  LS22 6SN
# 14             1986-11-21   NW3 1EH
# 15             1899-07-27    N6 5HF
# 16             2006-05-16  BT78 1LE
# 17             2004-08-20   NW7 2DQ
# 18             1996-12-19   SG6 9BL
# 19             1984-03-07   WF8 4BG
# 20             1985-10-02   TQ1 3NT
# 21             1998-07-03  BT82 8DX
# 22             1965-06-14   BR3 5BZ
# 23             2009-03-02   B18 6EW
# 24             1998-07-29   IG1 1BA
# ...

# %%
sic18 = sic18.set_index('SIC2018')

# %%
sicdata18= sicdata18.set_index('SIC2018')

# %%
len(sicdata18)
# Out:
# 27605

# %%
sicdata18.to_csv('sicdata18.csv',index=True)

# %%
sic18.to_csv('sic18_complete.csv',index=True)

# %%
startup2018
# Out:
#         incorporationdate  postcode  \
# 1114082        2013-01-02   SA1 3EZ
# 1114142        2013-01-02   N12 0DR
# 1114183        2013-01-02   S36 1GA
# 1114185        2013-01-02   PE2 6PZ
# 1114240        2013-01-02  CH64 4BA
# 1114245        2013-01-02   LE7 7JU
# 1114251        2013-01-02    N3 1AR
# 1114282        2013-01-02  NG18 3EG
# 1114297        2013-01-02   B75 5ET
# 1114307        2013-01-02   HG3 2SY
# 1114316        2013-01-02   CB8 8FE
# 1114373        2013-01-02   EX1 2BJ
# 1114390        2013-01-02  LS10 2RU
# 1114403        2013-01-02   W14 9AP
# 1114420        2013-01-02   LE1 7EA
# 1114431        2013-01-02   N10 3AG
# 1114435        2013-01-02   AL3 4NG
# 1114458        2013-01-02   IG1 1TE
# 1114481        2013-01-02  GU30 7AZ
# 1114493        2013-01-02   DN6 8DA
# 1114498        2013-01-02   NN7 1BA
# 1114547        2013-01-02  LS28 6QB
# 1114598        2013-01-02   NR1 3PL
# 1114599        2013-01-02   W11 1AP
# 1114601        2013-01-02  TR11 4AB
# ...

# %%
sic_digital
# Out:
# [26110,
#  26120,
#  26200,
#  26400,
#  26511,
#  26512,
#  26800,
#  33130,
#  58210,
#  58290,
#  62011,
#  62012,
#  62020,
#  62030,
#  62090,
#  63110,
#  63120,
#  95110]

# %%
sic18_digital=sic18.iloc[sic_digital]
#sicdata18_science= sicdata18.iloc[sic_science]

# %%
sic18_digital
# Out:
#          postcode IncorporationDate  SIC_2013
# SIC2018
# 43999    CA10 3AS        18/03/2003     43999
# 46220    ME13 8SU        12/04/1996     46220
# 0         NR3 1AB        31/05/1979         0
# 99999     CT9 5HF        07/09/2000     45200
# 42990     EN8 9BH        06/09/2011     42990
# 4525      LS1 4JP        26/03/1986      4525
# 18129    CO13 0EP        30/12/1957     18129
# 96090     SL9 8HF        21/05/2004     96090
# 39000     B43 7QA        08/07/2010     39000
# 62090     TW1 3DY        28/12/2006     62090
# 82990     ML3 6DA        18/08/2011     82990
# 64999     W1J 5FJ        20/05/2003     64999
# 88910     NG1 1JU        02/03/2007     88910
# 74100     S10 2NH        26/09/2011     74100
# 0         PR3 1UA        18/09/1997         0
# 62020    SE23 1NG        06/11/2009     62020
# 68100    IP11 7SS        12/12/2011     68100
# 68320    BN11 1EG        03/12/1990     68320

# %%
sicdata18
# Out:
#          postcode IncorporationDate  SIC_2013 company2013 company2018
# SIC2018
# 47510     SA1 3EZ        2013-02-01         0      Active      Active
# 70229     N12 0DR        2013-02-01         0      Active      Active
# 74909     S36 1GA        2013-02-01         0      Active      Active
# 41202     PE2 6PZ        2013-02-01         0      Active      Active
# 69202    CH64 4BA        2013-02-01         0      Active      Active
# 82990     LE7 7JU        2013-02-01         0      Active      Active
# 43999      N3 1AR        2013-02-01         0      Active      Active
# 43999    NG18 3EG        2013-02-01         0      Active      Active
# 86900     B75 5ET        2013-02-01         0      Active      Active
# 81291     HG3 2SY        2013-02-01         0      Active      Active
# 73110     CB8 8FE        2013-02-01         0      Active      Active
# 80300     EX1 2BJ        2013-02-01         0      Active      Active
# ...

# %%
sicdata13.iloc[sic_digital]
# Out:
#          incorporationdate  postcode  SIC2018 company2013 company2018
# SIC_2013
# 96090           2009-05-26  NG10 5EH    96090      Active      Active
# 96090           2009-05-26  AB42 3GL    96090      Active      Active
# 56102           2009-05-27  SE10 9JA    56102      Active      Active
# 99999           2009-05-27   DY8 2HG    99999      Active      Active
# 70229           2009-05-28   B13 9BY    70229      Active      Active
# 33120           2009-05-28  TS17 0RB    33120      Active      Active
# 82990           2009-05-29   WA1 1RG    82990      Active      Active
# 45112           2009-07-03   B45 9DR    45112      Active      Active
# 69201           2009-11-19    N7 6NJ    69201      Active      Active
# 52290           2009-11-19  LE65 2NN    52290      Active      Active
# 46180           2009-12-09  CT12 6SR    46180      Active      Active
# 70229           2009-12-09  GL54 1AF    70229      Active      Active
# ...

# %%
sicdata18_digital.to_csv('sicdata18_digital.csv',index=False)
sicdata18_science.to_csv('sicdata18_science.csv',index=False)

# %%
sicdata13.iloc[sic_retail],['companycategory','companystatus']
# Out:
# (         incorporationdate  postcode  \
#  SIC_2013
#  70229           2006-03-23  SE24 0PQ
#  82990           1995-08-11   NW9 9TY
#  79110           2008-11-19   E11 2PU
#  70229           2004-04-14   AL4 8SB
#  32990           1988-05-11  WA12 0LF
#  10710           2009-08-26   E17 4PP
#  81223           2011-03-30  AB39 2DN
#  32990           1975-05-19  RG12 2UW
#  58190           2004-12-02   SP5 2BY
#  74909           2011-02-23  RM17 6BU
#  88990           2009-05-15   PR8 4PH
#  56210           2009-09-07   M14 5WG
#  47599           2001-05-23   LN2 4PX
#  64921           2004-02-13    M2 6XX
#  85590           2003-11-19  KT16 0QL
#  70229           2009-12-18   ST5 2BE
#  63990           2010-06-02   SE1 8SJ
#  56103           2010-11-29   E16 3RW
#  68209           1991-02-05  BT62 4HG
#  49410           2011-03-14  TN33 0AG
#  0               1971-05-06   W1R 5HB
#  74909           2011-12-16   SE1 2DA
#  70229           2007-03-16  TW14 9LE
# ...

# %%
sicdata13['companystatus']
# Out:
# SIC_2013
# 90010         Active
# 70229         Active
# 99999         Active
# 56101         Active
# 86230         Active
# 68209         Active
# 82990         Active
# 82990         Active
# 0        Liquidation
# 68209         Active
# 68320         Active
# 56101         Active
# 85310         Active
# 45310         Active
# 99999         Active
# 85200         Active
# 41100         Active
# 96090         Active
# 47591         Active
# 86101         Active
# 98000         Active
# 14132         Active
# 98000         Active
# 82990         Active
# 61900         Active
# 90020         Active
# 0             Active
# 41202         Active
# 96010         Active
# 52230         Active
#             ...
# 0        Liquidation
# 0        Liquidation
# 0             Active
# 0             Active
# 0             Active
# 0        Liquidation
# 0             Active
# 0             Active
# 0             Active
# 0             Active
# 0             Active
# 0        Liquidation
# ...

# %%
#this will add column for company status in 2013 sic
sicdata13['company2013'] = np.where(sicdata13['companystatus']=='Active','Active','NotActive')

# %%
#this will add column for company status for 2018 in 2013 sic
sicdata13['company2018'] = np.where(sicdata13['CompanyStatus']=='Active','Active','NotActive')

# %%
sicdata13.columns
# Out:
# Index(['incorporationdate', 'postcode', 'companycategory', 'companystatus',
#        'CompanyCategory', 'CompanyStatus', 'IncorporationDate', 'SIC2018',
#        'SICcombine', 'company2013', 'company2018'],
#       dtype='object')

# %%
sicdata13.dtypes
# Out:
# incorporationdate     object
# postcode              object
# companycategory       object
# companystatus         object
# CompanyCategory       object
# CompanyStatus         object
# IncorporationDate     object
# SIC2018                int64
# SICcombine           float64
# company2013           object
# dtype: object

# %%
sicdata18= data.set_index('SIC2018')

# %%
sicdata13.head(3)
# Out:
#          incorporationdate  postcode          companycategory companystatus  \
# SIC_2013
# 90010           1992-05-12   SE4 1NQ  Private Limited Company        Active
# 70229           1999-07-22  TN11 9PL  Private Limited Company        Active
# 99999           2007-11-28  GU21 5TS  Private Limited Company        Active
#
#                   CompanyCategory CompanyStatus IncorporationDate  SIC2018  \
# SIC_2013
# 90010     Private Limited Company        Active        12/05/1992    90010
# 70229     Private Limited Company        Active        22/07/1999    70229
# 99999     Private Limited Company        Active        28/11/2007    99999
#
#           SICcombine company2013
# SIC_2013
# 90010        90010.0      Active
# 70229        70229.0      Active
# 99999        99999.0      Active

# %%
sicdata13['company2013']
# Out:
# SIC_2013
# 90010       Active
# 70229       Active
# 99999       Active
# 56101       Active
# 86230       Active
# 68209       Active
# 82990       Active
# 82990       Active
# 0        NotActive
# 68209       Active
# 68320       Active
# 56101       Active
# 85310       Active
# 45310       Active
# 99999       Active
# 85200       Active
# 41100       Active
# 96090       Active
# 47591       Active
# 86101       Active
# 98000       Active
# 14132       Active
# 98000       Active
# 82990       Active
# 61900       Active
# 90020       Active
# 0           Active
# 41202       Active
# 96010       Active
# 52230       Active
#            ...
# 0        NotActive
# 0        NotActive
# 0           Active
# 0           Active
# 0           Active
# 0        NotActive
# 0           Active
# 0           Active
# 0           Active
# 0           Active
# 0           Active
# 0        NotActive
# 0        NotActive
# 0        NotActive
# 0           Active
# 0           Active
# ...

# %%
sicdata13['company2018']
# Out:
# SIC_2013
# 90010       Active
# 70229       Active
# 99999       Active
# 56101       Active
# 86230       Active
# 68209       Active
# 82990       Active
# 82990       Active
# 0        NotActive
# 68209       Active
# 68320       Active
# 56101       Active
# 85310       Active
# 45310       Active
# 99999       Active
# 85200       Active
# 41100       Active
# 96090       Active
# 47591       Active
# 86101       Active
# 98000       Active
# 14132       Active
# 98000       Active
# 82990       Active
# 61900       Active
# 90020       Active
# 0           Active
# 41202       Active
# 96010       Active
# 52230       Active
#            ...
# 0        NotActive
# 0        NotActive
# 0           Active
# 0           Active
# 0           Active
# 0        NotActive
# 0           Active
# 0           Active
# 0           Active
# 0           Active
# 0           Active
# 0        NotActive
# 0        NotActive
# 0        NotActive
# 0           Active
# 0           Active
# ...

# %%
(sicdata13.iloc[sic_entertainment])
# Out:
#          incorporationdate  postcode          companycategory companystatus  \
# SIC_2013
# 99999           1993-11-22  SW15 2QT  Private Limited Company        Active
# 74909           2009-04-16   HU3 6UU  Private Limited Company        Active
# 41100           2011-03-21   DN5 9EZ  Private Limited Company        Active
# 70229           2008-09-12    W5 5NW  Private Limited Company        Active
# 0               2003-06-17   L33 7XL      Limited Partnership        Active
# 0               1999-02-19   N17 9LN      Limited Partnership        Active
# 0               2011-06-16   L33 7TX      Limited Partnership        Active
# 0               1999-04-19   N17 9LN      Limited Partnership        Active
# 0               2003-06-17    L3 9LQ      Limited Partnership        Active
# 0               1998-08-18   N17 9LN      Limited Partnership        Active
# 62090           1993-02-10  EC3R 7QR  Private Limited Company        Active
# ...

# %%
(sicdata13.iloc[sic_food])
# Out:
#          incorporationdate  postcode          companycategory companystatus  \
# SIC_2013
# 68209           2004-03-18   WF8 3JS  Private Limited Company        Active
# 31010           2009-10-22   RG4 8AX  Private Limited Company        Active
# 43999           2006-06-01  EX34 9AU  Private Limited Company        Active
# 74990           2003-06-24   WV5 8JP  Private Limited Company        Active
# 69201           1979-08-21   B49 6QL  Private Limited Company        Active
# 47990           2008-03-07  EX17 6YQ  Private Limited Company        Active
# 68320           1999-02-11    W4 1ER  Private Limited Company        Active
# 74990           1996-04-30  LS21 1EE  Private Limited Company        Active
# 0               2012-04-13  PA12 4AB  Private Limited Company        Active
# 74902           2011-09-26   NN2 6QY  Private Limited Company        Active
# 93120           2010-01-28  PE19 7RE  Private Limited Company        Active
# ...

# %%
(sicdata13.iloc[sic_otherScManuf])
# Out:
#          incorporationdate  postcode  \
# SIC_2013
# 98000           1999-12-09    N5 2PZ
# 98000           2007-04-12  CT10 1NG
# 98000           1986-02-27   N19 5RR
# 98000           2009-05-28   BN1 3TL
# 98000           1983-08-01   BS8 3AS
# 98000           2001-06-26   HA7 4XR
# 70229           2011-08-08  BT48 7NR
# 68209           2002-03-12  BT48 0LU
# 68320           2001-08-10   N21 1LU
# 68209           1985-11-05   SE3 7TD
# 98000           1998-09-17  SW10 9DU
# 98000           2003-06-05   N15 6PR
# 68320           1989-03-31  OX16 5BL
# 98000           1994-07-11    W9 3EA
# 98000           1983-06-20   NW2 3TL
# 56302           1999-08-16    E1 6QN
# 68320           2003-05-07   NW3 6NX
# 98000           1997-10-03   NW6 2QY
# 98000           1993-10-25    N6 5LW
# 68320           1997-11-06  BS20 6EG
# 68100           2006-12-22   NW4 1SH
# 98000           2003-10-03  RG17 0NF
# 98000           2011-05-11  KT17 1RX
# 43390           2011-11-28  WA12 8BB
# ...

# %%
(sicdata13.iloc[sic_otherScServices])
# Out:
#          incorporationdate  postcode  \
# SIC_2013
# 68209           1964-07-24  NW11 7RJ
# 25620           1987-01-12   SK7 5AA
# 49320           2009-03-23   MK2 2DZ
# 7020            2002-08-15   PR1 8BU
# 74990           2010-09-09  BT28 1TP
# 99000           2011-03-21  BT28 1TP
# 47540           1995-05-10  WS11 7LT
# 81300           2011-05-05   CR0 0EE
# 43330           2008-10-02   CR0 8DN
# 20412           2010-08-18   ML3 6JP
# 47220           2007-11-02   SR7 0LP
# 78109           2009-03-24   FY4 1EW
# 70229           2010-04-28   LU2 7DL
# 62012           2001-03-05   B27 6AG
# 33140           2000-12-19  PO22 7RA
# 69203           1995-08-11   UB8 3AU
# 82990           2005-08-03  BN18 9LS
#
#                                             companycategory companystatus  \
# SIC_2013
# 68209                               Private Limited Company        Active
# 25620                               Private Limited Company        Active
# ...

# %%
(sicdata13.iloc[sic_publishing])
# Out:
#          incorporationdate  postcode  \
# SIC_2013
# 86900           2000-09-26   CH1 2DS
# 74909           2008-02-25  NR16 1ER
# 0               1974-02-13   L61 5UT
# 99999           2005-02-17   NW9 0NH
# 81299           2011-07-08  WA11 8AW
# 81100           2007-05-24  SE25 6AQ
# 43290           2003-03-28   LE9 7AE
# 32990           2007-07-30  BD16 4ED
# 81300           2011-10-18   WD3 1DE
# 82990           1972-02-24   GL1 1JZ
# 96090           2003-03-25  CB22 3JJ
# 81210           2007-03-05  SO23 9EH
# 43220           2006-08-10  WA15 7BB
# 35300           2007-05-02   PO9 2LJ
# 46900           1997-07-14  BN27 1DQ
# 46900           1980-10-15   LS1 5AB
# 99999           1993-11-22  SW15 2QT
# 49410           1982-09-23  DE55 4QQ
# 41100           2004-09-29   BN1 3XG
# 43310           2011-05-13   PL4 8JY
# 70229           1998-05-21   GU9 7NU
# 82990           2009-03-10   SG8 5HL
# 59200           2005-05-09   BN1 6SB
# 72190           2011-09-29   LU4 8QU
# ...

# %%
(sicdata13.iloc[sic_science])
# Out:
#          incorporationdate  postcode          companycategory companystatus  \
# SIC_2013
# 47110           2007-11-21   NN3 2PU  Private Limited Company        Active
# 71129           2011-03-11   NR7 0HR  Private Limited Company        Active
# 43999           2006-03-07   CB8 9PA  Private Limited Company        Active
# 24330           1972-02-04   SS9 2UJ  Private Limited Company        Active
# 62020           1995-01-31  BS21 7EY  Private Limited Company        Active
# 62020           1996-06-28  TQ12 6ED  Private Limited Company        Active
# 0               2007-02-16   GY1 2HJ      Limited Partnership        Active
# 64921           2011-10-18    M2 6XX  Private Limited Company        Active
# 62020           1994-05-11  WR15 8JY  Private Limited Company        Active
# 98000           2008-07-17   L22 0ND  Private Limited Company        Active
# 99999           1999-03-29   WD6 1QQ  Private Limited Company        Active
# ...
